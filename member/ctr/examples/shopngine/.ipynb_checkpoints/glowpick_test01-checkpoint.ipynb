# %%
import sys
sys.path.append("..")

import common
from common import FILE_PATH
from common import MODEL_PATH

import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from deepctr_torch.inputs import SparseFeat, VarLenSparseFeat, get_feature_names
from deepctr_torch.models import DeepFM
import pickle

# %load_ext autoreload
# %autoreload 2
import product_refine

st = sns.axes_style("whitegrid")
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})

plt.rcParams ['font.family'] = 'NanumGothic'

import warnings
warnings.filterwarnings("ignore")

# %%
# %load_ext autoreload
# %autoreload 2
import product_refine

# %%
# %%time

reviews = pd.read_feather (FILE_PATH + 'reviews.ftr', use_threads = True)
users = pd.read_feather (FILE_PATH + 'users.ftr', use_threads = True)
products = pd.read_feather (FILE_PATH + 'products.ftr', use_threads = True)
product_categories = pd.read_feather (FILE_PATH + 'product_categories.ftr', use_threads = True)
# Out:
# CPU times: user 3.12 s, sys: 840 ms, total: 3.95 s
# Wall time: 3.72 s

# %%
# %%time
df_products = product_refine.refine_products (products)
# Out:
# len del_id_list:  1355
#
# CPU times: user 5.03 s, sys: 126 ms, total: 5.16 s
# Wall time: 5.06 s

# %%
users.head ()
# Out:
#     age  birth_year                     email gender  is_blinded  is_closed  \
# 0  31.0      1990.0          yhcu88@naver.com      f           0      False
# 1  33.0      1988.0    winwinanna@hanmail.net      f           0      False
# 2  37.0      1984.0  dmswjddlskfk@hanmail.net      f           0      False
# 3  32.0      1989.0         deer402@naver.com      f           0      False
# 4  26.0      1995.0         kkr3348@naver.com      f           0      False
#
#    is_inactivated     nickname  \
# 0           False          희뷰리
# 1           False       소극적인뷰터
# 2           False  greengables
# 3            True          백비송
# 4           False         초코감귤
#
#                                        profile_image   rank  review_count  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  27347            44
# 1                                               None  41582            15
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...    946           375
# 3  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  43404            29
# 4  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...   9386            97
#
#   skin_type  user_id
# 0       복합성  1281918
# 1        건성  1255686
# 2        지성   631689
# 3        건성  1188087
# 4       복합성   632220

# %%
len (users ['age'].unique ())
# Out:
# 79

# %%
# 100세 이상, 음수나이, 연도를 나이로 입력한듯한 나이(2016, 2018, 1995)등이 보임
users ['age'].value_counts ().tail (32)
# Out:
#  57.0      14
#  121.0     11
#  58.0      11
#  7.0       11
#  12.0      10
#  3.0        9
#  2.0        9
#  60.0       8
#  104.0      6
#  62.0       5
#  61.0       5
#  11.0       5
#  101.0      5
#  59.0       4
#  72.0       2
#  103.0      2
#  71.0       2
#  102.0      2
#  64.0       2
#  8.0        2
#  63.0       2
#  105.0      2
# -518.0      1
#  67.0       1
#  70.0       1
#  9.0        1
#  89.0       1
#  98.0       1
#  2016.0     1
#  68.0       1
#  2018.0     1
#  1995.0     1
# Name: age, dtype: int64

# %%
users.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76490 entries, 0 to 76489
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             76489 non-null  float64
#  1   birth_year      76489 non-null  float64
#  2   email           76490 non-null  object
#  3   gender          76490 non-null  object
#  4   is_blinded      76490 non-null  int64
#  5   is_closed       76490 non-null  bool
#  6   is_inactivated  76490 non-null  bool
#  7   nickname        76489 non-null  object
#  8   profile_image   44893 non-null  object
#  9   rank            76490 non-null  int64
#  10  review_count    76490 non-null  int64
#  11  skin_type       76490 non-null  object
#  12  user_id         76490 non-null  object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 6.6+ MB

# %%
# 0세 ~ 90세 회원 정보만 뽑아냄.  음수나이와 90세 이상은 제외
users = users [(users ['age'] < 90) & (users ['age'] > 0)]
users.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76456 entries, 0 to 76489
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             76456 non-null  float64
#  1   birth_year      76456 non-null  float64
#  2   email           76456 non-null  object
#  3   gender          76456 non-null  object
#  4   is_blinded      76456 non-null  int64
#  5   is_closed       76456 non-null  bool
#  6   is_inactivated  76456 non-null  bool
#  7   nickname        76455 non-null  object
#  8   profile_image   44871 non-null  object
#  9   rank            76456 non-null  int64
#  10  review_count    76456 non-null  int64
#  11  skin_type       76456 non-null  object
#  12  user_id         76456 non-null  object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 7.1+ MB

# %%
users.describe ()
# Out:
#                 age    birth_year  is_blinded          rank  review_count
# count  76456.000000  76456.000000     76456.0  7.645600e+04  76456.000000
# mean      25.250118   1995.749882         0.0  6.909060e+04     41.476823
# std        5.984109      5.984109         0.0  5.044060e+05     56.878904
# min        2.000000   1932.000000         0.0  1.000000e+00    -46.000000
# 25%       21.000000   1993.000000         0.0  1.853600e+04     10.000000
# 50%       25.000000   1996.000000         0.0  3.840400e+04     26.000000
# 75%       28.000000   2000.000000         0.0  6.279600e+04     51.000000
# max       89.000000   2019.000000         0.0  9.999999e+06   2003.000000

# %%
review_user_df = pd.merge (reviews, users, how = 'left', on = 'user_id')
review_user_df.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    is_evaluation  like_count  rating review_id state  user_id product_id  \
# 0          False           0       3   5416271     N   119763     100000
# 1          False           0       4   5340616     N   338669     100000
# 2          False           0       3   5228598     N    24862     100000
# 3          False           0       4   5225359     N  1331797     100000
# 4          False           0       4   5211274     N   888968     100000
#
#     age  ...                   email gender is_blinded  is_closed  \
# 0  36.0  ...     intears23@naver.com      f        0.0      False
# 1  38.0  ...   hihearyeong@naver.com      f        0.0      False
# 2  28.0  ...     leemj1993@naver.com      f        0.0      False
# 3  20.0  ...    betcha2001@naver.com      f        0.0      False
# 4  33.0  ...  milk_madam@hanmail.net      f        0.0      False
#
#   is_inactivated nickname                                      profile_image  \
# 0          False      kyo  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 1          False       뭐라  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...
# 2          False       민졍                                               None
# 3          False  Gravity                                               None
# 4          False     이게모람  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
#
#       rank  review_count  skin_type
# 0   2914.0         205.0        복합성
# 1   1023.0         285.0         중성
# 2   2292.0         230.0        복합성
# 3  36233.0          36.0        복합성
# 4   6737.0         108.0        복합성
#
# [5 rows x 21 columns]

# %%
len (reviews)
# Out:
# 1574817

# %%
len (review_user_df)
# Out:
# 1574817

# %%
review_user_product_df = pd.merge (review_user_df, df_products, how = 'left', on = 'product_id')
review_user_product_df.head (3)
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
#
#    is_evaluation  like_count  rating review_id state user_id product_id   age  \
# 0          False           0       3   5416271     N  119763     100000  36.0
# 1          False           0       4   5340616     N  338669     100000  38.0
# 2          False           0       3   5228598     N   24862     100000  28.0
#
#    ...    price reviewCnt ratingAvg  \
# 0  ...  11000.0      11.0      3.64
# 1  ...  11000.0      11.0      3.64
# 2  ...  11000.0      11.0      3.64
#
#                                           productImg isDiscontinue rankChange  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 1  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
#
#   rankChangeType                                              brand  \
# 0           show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 1           show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 2           show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
#
#            goodsInfo          brandName
# 0  {'goodsCount': 0}  해피바스 (HAPPY BATH)
# 1  {'goodsCount': 0}  해피바스 (HAPPY BATH)
# 2  {'goodsCount': 0}  해피바스 (HAPPY BATH)
#
# [3 rows x 34 columns]

# %%
len (review_user_product_df)
# Out:
# 1574817

# %% [markdown]
# ### product_categoreis

# %%
product_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88756 entries, 0 to 88755
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   firstCategoryText   88756 non-null  object
#  1   idFirstCategory     88756 non-null  int64
#  2   idSecondCategory    88756 non-null  int64
#  3   idThirdCategory     88756 non-null  int64
#  4   secondCategoryText  88756 non-null  object
#  5   thirdCategoryText   88704 non-null  object
#  6   product_id          88756 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 4.7+ MB

# %%
product_categories.isnull ().sum ()
# Out:
# firstCategoryText      0
# idFirstCategory        0
# idSecondCategory       0
# idThirdCategory        0
# secondCategoryText     0
# thirdCategoryText     52
# product_id             0
# dtype: int64

# %%
product_categories ['idThirdCategory'].nunique ()
# Out:
# 291

# %%
# 하나의 상품마다 2 이상의 카테고리를 가질수 있음
product_categories ['product_id'].value_counts ().head (50)
# Out:
# 3754      38
# 1558      26
# 22223     23
# 90430     19
# 74532     19
# 51029     18
# 74539     17
# 9864      17
# 43452     16
# 114984    15
# 2766      15
# 28106     15
# 132371    15
# 55517     14
# 3245      13
# 2851      11
# 133407     7
# 4          7
# 85537      7
# 89452      6
# 74574      6
# 108331     6
# 90958      6
# 19695      6
# 433        5
# 86217      5
# 114608     5
# 64325      5
# 83589      5
# 97465      5
# 102742     5
# 42288      5
# 22476      5
# 112778     5
# 50745      5
# 6530       5
# 51869      5
# 105349     5
# 90840      5
# 91298      5
# 40668      5
# 15279      5
# 12221      5
# 76752      5
# 77355      5
# 100129     5
# 11734      5
# 35706      5
# 3159       4
# 34291      4
# Name: product_id, dtype: int64

# %%
products [products ['product_id'] == '1030']
# Out:
#       product_id rank          title volume  price reviewCnt ratingAvg  \
# 38683       1030   10  알파인 베리 워터리 크림   50ml  37000      2222      4.09
#
#                                               productImg isDiscontinue  \
# 38683  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#       rankChange rankChangeType  \
# 38683         -1           show
#
#                                                    brand          goodsInfo
# 38683  {'idBrand': None, 'brandTitle': '프리메라 (primera...  {'goodsCount': 0}

# %%
product_categories [product_categories ['product_id'] == '1030']
# Out:
#       firstCategoryText  idFirstCategory  idSecondCategory  idThirdCategory  \
# 2                 립메이크업                3                15               50
# 10033              스킨케어                1                 3               17
# 82433                헤어               11                65              198
#
#       secondCategoryText thirdCategoryText product_id
# 2                 립틴트/라커           글로시/젤틴트       1030
# 10033             에센스/세럼          안티에이징에센스       1030
# 82433               헤어케어          헤어에센스/세럼       1030

# %%
product_categories [product_categories ['product_id'] == '1030']
# Out:
#       firstCategoryText  idFirstCategory  idSecondCategory  idThirdCategory  \
# 2                 립메이크업                3                15               50
# 10033              스킨케어                1                 3               17
# 82433                헤어               11                65              198
#
#       secondCategoryText thirdCategoryText product_id
# 2                 립틴트/라커           글로시/젤틴트       1030
# 10033             에센스/세럼          안티에이징에센스       1030
# 82433               헤어케어          헤어에센스/세럼       1030

# %%
# 상품별 중복 row를 삭제. 하나의 상품당 하나의 카테고리 (first > second > third)만
categories_drop_dupli = product_categories.drop_duplicates ('product_id')
categories_drop_dupli
# Out:
#       firstCategoryText  idFirstCategory  idSecondCategory  idThirdCategory  \
# 0                 프래그런스               15                83              246
# 1                   클렌징                7                32              112
# 2                 립메이크업                3                15               50
# 3                 립메이크업                3                17               54
# 4                아이메이크업                4                22               75
# ...                 ...              ...               ...              ...
# 88751                헤어               11                62              197
# 88752                헤어               11                62              197
# 88753                헤어               11                62              197
# 88754                헤어               11                62              196
# 88755                헤어               11                62              196
#
#       secondCategoryText thirdCategoryText product_id
# 0                     향수              여성향수      10000
# 1                 페이셜클렌저              클렌징폼     100000
# 2                 립틴트/라커           글로시/젤틴트       1030
# 3                   립글로스              립글로스     100002
# 4                  아이섀도우             아이팔레트      88268
# ...                  ...               ...        ...
# 88751            트리트먼트/팩           헤어마스크/팩      99977
# 88752            트리트먼트/팩           헤어마스크/팩      99979
# 88753            트리트먼트/팩           헤어마스크/팩      99980
# 88754            트리트먼트/팩           헤어트리트먼트      99982
# 88755            트리트먼트/팩           헤어트리트먼트      99988
#
# [79227 rows x 7 columns]

# %%
categories_drop_dupli ['idFirstCategory'].nunique ()
# Out:
# 19

# %%
categories_drop_dupli ['idSecondCategory'].nunique ()
# Out:
# 90

# %%
categories_drop_dupli ['idThirdCategory'].nunique ()
# Out:
# 291

# %%
categories_drop_dupli.isnull ().sum ()
# Out:
# firstCategoryText      0
# idFirstCategory        0
# idSecondCategory       0
# idThirdCategory        0
# secondCategoryText     0
# thirdCategoryText     48
# product_id             0
# dtype: int64

# %%
categories_drop_dupli.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79227 entries, 0 to 88755
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   firstCategoryText   79227 non-null  object
#  1   idFirstCategory     79227 non-null  int64
#  2   idSecondCategory    79227 non-null  int64
#  3   idThirdCategory     79227 non-null  int64
#  4   secondCategoryText  79227 non-null  object
#  5   thirdCategoryText   79179 non-null  object
#  6   product_id          79227 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 4.8+ MB

# %%
categories_drop_dupli ['product_id'].value_counts ()
# Out:
# 84484     1
# 102644    1
# 133228    1
# 18520     1
# 65245     1
#          ..
# 12522     1
# 96515     1
# 15710     1
# 7138      1
# 116498    1
# Name: product_id, Length: 79227, dtype: int64

# %%
categories_drop_dupli [categories_drop_dupli ['product_id'] == '2851']
# Out:
#      firstCategoryText  idFirstCategory  idSecondCategory  idThirdCategory  \
# 1102             배쓰&바디               10                57              173
#
#      secondCategoryText thirdCategoryText product_id
# 1102              배쓰/샤워              바디워시       2851

# %% [markdown]
# ### merge
#
# review_user_product_df, categories_drop_dupli

# %%
total_merged_df = pd.merge (review_user_product_df, categories_drop_dupli, how = 'left', on = 'product_id')
total_merged_df.head (3)
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
#
#    is_evaluation  like_count  rating review_id state user_id product_id   age  \
# 0          False           0       3   5416271     N  119763     100000  36.0
# 1          False           0       4   5340616     N  338669     100000  38.0
# 2          False           0       3   5228598     N   24862     100000  28.0
#
#    ...  rankChangeType                                              brand  \
# 0  ...            show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 1  ...            show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 2  ...            show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
#
#            goodsInfo          brandName firstCategoryText idFirstCategory  \
# 0  {'goodsCount': 0}  해피바스 (HAPPY BATH)               클렌징             7.0
# 1  {'goodsCount': 0}  해피바스 (HAPPY BATH)               클렌징             7.0
# 2  {'goodsCount': 0}  해피바스 (HAPPY BATH)               클렌징             7.0
#
#   idSecondCategory idThirdCategory  secondCategoryText  thirdCategoryText
# 0             32.0           112.0              페이셜클렌저               클렌징폼
# 1             32.0           112.0              페이셜클렌저               클렌징폼
# 2             32.0           112.0              페이셜클렌저               클렌징폼
#
# [3 rows x 40 columns]

# %%
len (review_user_product_df)
# Out:
# 1574817

# %%
len (total_merged_df)
# Out:
# 1574817

# %%
total_merged_df.columns
# Out:
# Index(['contents', 'created_at', 'is_evaluation', 'like_count', 'rating',
#        'review_id', 'state', 'user_id', 'product_id', 'age', 'birth_year',
#        'email', 'gender', 'is_blinded', 'is_closed', 'is_inactivated',
#        'nickname', 'profile_image', 'rank_x', 'review_count', 'skin_type',
#        'rank_y', 'title', 'volume', 'price', 'reviewCnt', 'ratingAvg',
#        'productImg', 'isDiscontinue', 'rankChange', 'rankChangeType', 'brand',
#        'goodsInfo', 'brandName', 'firstCategoryText', 'idFirstCategory',
#        'idSecondCategory', 'idThirdCategory', 'secondCategoryText',
#        'thirdCategoryText'],
#       dtype='object')

# %%
total_merged_df.head (1)
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
#
#    is_evaluation  like_count  rating review_id state user_id product_id   age  \
# 0          False           0       3   5416271     N  119763     100000  36.0
#
#    ...  rankChangeType                                              brand  \
# 0  ...            show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
#
#            goodsInfo          brandName firstCategoryText idFirstCategory  \
# 0  {'goodsCount': 0}  해피바스 (HAPPY BATH)               클렌징             7.0
#
#   idSecondCategory idThirdCategory  secondCategoryText  thirdCategoryText
# 0             32.0           112.0              페이셜클렌저               클렌징폼
#
# [1 rows x 40 columns]

# %%
get_cols = ['contents', 'created_at', 'rating', 'user_id', 'product_id', 'age', 'gender', 'is_blinded', 'is_closed', 'is_inactivated', 'skin_type', 'title', 'volume', 'price', 'brandName', 'idThirdCategory']

# %%
glowpick = total_merged_df [get_cols]
glowpick.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    rating  user_id product_id   age gender  is_blinded is_closed  \
# 0       3   119763     100000  36.0      f         0.0     False
# 1       4   338669     100000  38.0      f         0.0     False
# 2       3    24862     100000  28.0      f         0.0     False
# 3       4  1331797     100000  20.0      f         0.0     False
# 4       4   888968     100000  33.0      f         0.0     False
#
#   is_inactivated skin_type              title volume    price  \
# 0          False       복합성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 1          False        중성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 2          False       복합성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 3          False       복합성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 4          False       복합성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
#
#            brandName  idThirdCategory
# 0  해피바스 (HAPPY BATH)            112.0
# 1  해피바스 (HAPPY BATH)            112.0
# 2  해피바스 (HAPPY BATH)            112.0
# 3  해피바스 (HAPPY BATH)            112.0
# 4  해피바스 (HAPPY BATH)            112.0

# %%
total_merged_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1574817 entries, 0 to 1574816
# Data columns (total 40 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   contents            1574817 non-null  object
#  1   created_at          1574817 non-null  object
#  2   is_evaluation       1574817 non-null  bool
#  3   like_count          1574817 non-null  int64
#  4   rating              1574817 non-null  int64
#  5   review_id           1574817 non-null  object
#  6   state               1574817 non-null  object
#  7   user_id             1574817 non-null  object
#  8   product_id          1574817 non-null  object
#  9   age                 1472144 non-null  float64
#  10  birth_year          1472144 non-null  float64
#  11  email               1472144 non-null  object
#  12  gender              1472144 non-null  object
#  13  is_blinded          1472144 non-null  float64
#  14  is_closed           1472144 non-null  object
#  15  is_inactivated      1472144 non-null  object
#  16  nickname            1472133 non-null  object
#  17  profile_image       1025674 non-null  object
#  18  rank_x              1472144 non-null  float64
#  19  review_count        1472144 non-null  float64
#  20  skin_type           1472144 non-null  object
#  21  rank_y              1564554 non-null  float64
#  22  title               1564554 non-null  object
#  23  volume              1564554 non-null  object
#  24  price               1564257 non-null  float64
#  25  reviewCnt           1564554 non-null  float64
#  26  ratingAvg           1564554 non-null  float64
#  27  productImg          1564552 non-null  object
#  28  isDiscontinue       1564554 non-null  object
#  29  rankChange          1564554 non-null  object
#  30  rankChangeType      1564554 non-null  object
#  31  brand               1564554 non-null  object
#  32  goodsInfo           1564554 non-null  object
#  33  brandName           1564554 non-null  object
#  34  firstCategoryText   1520133 non-null  object
#  35  idFirstCategory     1520133 non-null  float64
#  36  idSecondCategory    1520133 non-null  float64
#  37  idThirdCategory     1520133 non-null  float64
#  38  secondCategoryText  1520133 non-null  object
#  39  thirdCategoryText   1519737 non-null  object
# dtypes: bool(1), float64(12), int64(2), object(25)
# memory usage: 482.1+ MB

# %%
glowpick.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1574817 entries, 0 to 1574816
# Data columns (total 16 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   contents         1574817 non-null  object
#  1   created_at       1574817 non-null  object
#  2   rating           1574817 non-null  int64
#  3   user_id          1574817 non-null  object
#  4   product_id       1574817 non-null  object
#  5   age              1472144 non-null  float64
#  6   gender           1472144 non-null  object
#  7   is_blinded       1472144 non-null  float64
#  8   is_closed        1472144 non-null  object
#  9   is_inactivated   1472144 non-null  object
#  10  skin_type        1472144 non-null  object
#  11  title            1564554 non-null  object
#  12  volume           1564554 non-null  object
#  13  price            1564257 non-null  float64
#  14  brandName        1564554 non-null  object
#  15  idThirdCategory  1520133 non-null  float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 204.3+ MB

# %% [markdown]
# ### 결측치 삭제
#
# 1. 단순 삭제 모드

# %%
glowpick.isnull ().sum ()
# Out:
# contents                0
# created_at              0
# rating                  0
# user_id                 0
# product_id              0
# age                102673
# gender             102673
# is_blinded         102673
# is_closed          102673
# is_inactivated     102673
# skin_type          102673
# title               10263
# volume              10263
# price               10560
# brandName           10263
# idThirdCategory     54684
# dtype: int64

# %%
glowpick ['gender'].value_counts (dropna = False)
# Out:
# f      1457621
# NaN     102673
# m        14523
# Name: gender, dtype: int64

# %%
df_thresh = glowpick.dropna (axis = 1, thresh = 500)
df_thresh.isnull ().sum ()
# Out:
# contents                0
# created_at              0
# rating                  0
# user_id                 0
# product_id              0
# age                102673
# gender             102673
# is_blinded         102673
# is_closed          102673
# is_inactivated     102673
# skin_type          102673
# title               10263
# volume              10263
# price               10560
# brandName           10263
# idThirdCategory     54684
# dtype: int64

# %%
df_age = glowpick.dropna (subset = ['age'], how = 'any', axis = 0)
df_age.isnull ().sum ()
# Out:
# contents               0
# created_at             0
# rating                 0
# user_id                0
# product_id             0
# age                    0
# gender                 0
# is_blinded             0
# is_closed              0
# is_inactivated         0
# skin_type              0
# title               9542
# volume              9542
# price               9823
# brandName           9542
# idThirdCategory    51026
# dtype: int64

# %%
len (df_age)
# Out:
# 1472144

# %%
df_glowpick = glowpick.dropna (subset = ['age', 'title', 'price', 'idThirdCategory'], how = 'any', axis = 0)
df_glowpick.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1411866 entries, 0 to 1574816
# Data columns (total 16 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   contents         1411866 non-null  object
#  1   created_at       1411866 non-null  object
#  2   rating           1411866 non-null  int64
#  3   user_id          1411866 non-null  object
#  4   product_id       1411866 non-null  object
#  5   age              1411866 non-null  float64
#  6   gender           1411866 non-null  object
#  7   is_blinded       1411866 non-null  float64
#  8   is_closed        1411866 non-null  object
#  9   is_inactivated   1411866 non-null  object
#  10  skin_type        1411866 non-null  object
#  11  title            1411866 non-null  object
#  12  volume           1411866 non-null  object
#  13  price            1411866 non-null  float64
#  14  brandName        1411866 non-null  object
#  15  idThirdCategory  1411866 non-null  float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 183.1+ MB

# %%
df_glowpick.isnull ().sum ()
# Out:
# contents           0
# created_at         0
# rating             0
# user_id            0
# product_id         0
# age                0
# gender             0
# is_blinded         0
# is_closed          0
# is_inactivated     0
# skin_type          0
# title              0
# volume             0
# price              0
# brandName          0
# idThirdCategory    0
# dtype: int64

# %%
# 15만건 정도가 삭제됨
len (df_glowpick)
# Out:
# 1411866

# %%
len (glowpick)
# Out:
# 1574817

# %%
# sparse_features = ["product_id", "user_id", "gender", "age", "skin_type", "idThirdCategory", ]
sparse_features = ["product_id", "user_id", "gender", "age", "skin_type", ]
target = ['rating']

# %%
glowpick ['skin_type'].nunique ()
# Out:
# 5

# %%
from sklearn.preprocessing import LabelEncoder

# 1.Label Encoding for sparse features,and process sequence features
for feat in sparse_features:
    lbe = LabelEncoder()
    df_glowpick [feat] = lbe.fit_transform (df_glowpick [feat])

# %%
df_glowpick.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    rating  user_id  product_id  age  gender  is_blinded is_closed  \
# 0       3     7216           0   32       0         0.0     False
# 1       4    22803           0   34       0         0.0     False
# 2       3    19263           0   24       0         0.0     False
# 3       4    13371           0   16       0         0.0     False
# 4       4    68326           0   29       0         0.0     False
#
#   is_inactivated  skin_type              title volume    price  \
# 0          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 1          False          3  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 2          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 3          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 4          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
#
#            brandName  idThirdCategory
# 0  해피바스 (HAPPY BATH)            112.0
# 1  해피바스 (HAPPY BATH)            112.0
# 2  해피바스 (HAPPY BATH)            112.0
# 3  해피바스 (HAPPY BATH)            112.0
# 4  해피바스 (HAPPY BATH)            112.0

# %%
df_glowpick.sort_values (['product_id']).head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    rating  user_id  product_id  age  gender  is_blinded is_closed  \
# 0       3     7216           0   32       0         0.0     False
# 1       4    22803           0   34       0         0.0     False
# 2       3    19263           0   24       0         0.0     False
# 3       4    13371           0   16       0         0.0     False
# 4       4    68326           0   29       0         0.0     False
#
#   is_inactivated  skin_type              title volume    price  \
# 0          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 1          False          3  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 2          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 3          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 4          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
#
#            brandName  idThirdCategory
# 0  해피바스 (HAPPY BATH)            112.0
# 1  해피바스 (HAPPY BATH)            112.0
# 2  해피바스 (HAPPY BATH)            112.0
# 3  해피바스 (HAPPY BATH)            112.0
# 4  해피바스 (HAPPY BATH)            112.0

# %%
# 2.count #unique features for each sparse field and generate feature config for sequence feature

fixlen_feature_columns = [SparseFeat (feat, df_glowpick [feat].nunique(), embedding_dim=4)
                          for feat in sparse_features]
fixlen_feature_columns
# Out:
# [SparseFeat(name='product_id', vocabulary_size=49381, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='product_id', group_name='default_group'),
#  SparseFeat(name='user_id', vocabulary_size=74563, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='user_id', group_name='default_group'),
#  SparseFeat(name='gender', vocabulary_size=2, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='gender', group_name='default_group'),
#  SparseFeat(name='age', vocabulary_size=67, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='age', group_name='default_group'),
#  SparseFeat(name='skin_type', vocabulary_size=5, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='skin_type', group_name='default_group')]

# %%
linear_feature_columns = fixlen_feature_columns
dnn_feature_columns = fixlen_feature_columns
feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

# %%
feature_names
# Out:
# ['product_id', 'user_id', 'gender', 'age', 'skin_type']

# %%
# 3.generate input data for model
train, test = train_test_split (df_glowpick, test_size = 0.2)
train_model_input = {name: train [name] for name in feature_names}
test_model_input = {name: test [name] for name in feature_names}

# %%
device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'
# Out:
# cuda ready...

# %%
model = DeepFM (linear_feature_columns, dnn_feature_columns, task='regression', device=device)
model.compile ("adam", "mse", metrics=['mse'], )

# %%
# history = model.fit(train_model_input, train[target].values,
#                     batch_size=256, epochs = 10, verbose=2, validation_split=0.2, )

# %%
history = model.fit(train_model_input, train[target].values,
                    batch_size=256, epochs = 5, verbose=2, validation_split=0.2, )
# Out:
# cuda:0
# Train on 903593 samples, validate on 225899 samples, 3530 steps per epoch
# Epoch 1/5
# 32s - loss:  1.1101 - mse:  1.1101 - val_mse:  0.9982
# Epoch 2/5
# 33s - loss:  0.9248 - mse:  0.9248 - val_mse:  0.9967
# Epoch 3/5
# 30s - loss:  0.8964 - mse:  0.8964 - val_mse:  0.9827
# Epoch 4/5
# 31s - loss:  0.8798 - mse:  0.8798 - val_mse:  0.9852
# Epoch 5/5
# 32s - loss:  0.8668 - mse:  0.8668 - val_mse:  0.9876

# %%
# epoch 10
pred_ans = model.predict (test_model_input, batch_size = 256)
print("test MSE", round(mean_squared_error(
    test [target].values, pred_ans), 4))
# Out:
# test MSE 0.9817

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt (mean_squared_error (test [target].values, pred_ans))
print (rms)
# Out:
# 0.9908093043244933

# %%
# epoch 5

pred_ans = model.predict (test_model_input, batch_size = 256)
print("test MSE", round(mean_squared_error(
    test [target].values, pred_ans), 4))
# Out:
# test MSE 0.9817

# %%
print ("test RMSE", round (sqrt (mean_squared_error (test [target].values, pred_ans)), 4))
# Out:
# test RMSE 0.9908

# %%
test_model_input
# Out:
# {'product_id': 218533      9896
#  1096595    34455
#  963263     31023
#  518916     21329
#  922233     29872
#             ...
#  1419606    45533
#  1381016    44177
#  1029263    32568
#  748214     25711
#  992949     31973
#  Name: product_id, Length: 282374, dtype: int64,
#  'user_id': 218533     65640
#  1096595    32313
#  963263     45066
#  518916     49565
#  922233     19787
#             ...
#  1419606      819
#  1381016    74136
#  1029263    54732
#  748214     37712
#  992949     58810
#  Name: user_id, Length: 282374, dtype: int64,
#  'gender': 218533     0
#  1096595    0
#  963263     0
#  518916     0
#  922233     0
#            ..
#  1419606    0
#  1381016    0
#  1029263    0
#  748214     0
#  992949     0
#  Name: gender, Length: 282374, dtype: int64,
#  'age': 218533     17
#  1096595    17
#  963263     18
#  518916     25
#  922233     22
#             ..
#  1419606    17
#  1381016    14
#  1029263    18
#  748214     25
#  992949     17
#  Name: age, Length: 282374, dtype: int64,
#  'skin_type': 218533     0
#  1096595    1
#  963263     0
#  518916     2
#  922233     3
#            ..
#  1419606    0
#  1381016    0
#  1029263    2
#  748214     4
#  992949     4
#  Name: skin_type, Length: 282374, dtype: int64}

# %%
len (test_model_input)
# Out:
# 5

# %%
users.head ()
# Out:
#     age  birth_year                     email gender  is_blinded  is_closed  \
# 0  31.0      1990.0          yhcu88@naver.com      f           0      False
# 1  33.0      1988.0    winwinanna@hanmail.net      f           0      False
# 2  37.0      1984.0  dmswjddlskfk@hanmail.net      f           0      False
# 3  32.0      1989.0         deer402@naver.com      f           0      False
# 4  26.0      1995.0         kkr3348@naver.com      f           0      False
#
#    is_inactivated     nickname  \
# 0           False          희뷰리
# 1           False       소극적인뷰터
# 2           False  greengables
# 3            True          백비송
# 4           False         초코감귤
#
#                                        profile_image   rank  review_count  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  27347            44
# 1                                               None  41582            15
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...    946           375
# 3  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  43404            29
# 4  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...   9386            97
#
#   skin_type  user_id
# 0       복합성  1281918
# 1        건성  1255686
# 2        지성   631689
# 3        건성  1188087
# 4       복합성   632220

# %%
reviews.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    is_evaluation  like_count  rating review_id state  user_id product_id
# 0          False           0       3   5416271     N   119763     100000
# 1          False           0       4   5340616     N   338669     100000
# 2          False           0       3   5228598     N    24862     100000
# 3          False           0       4   5225359     N  1331797     100000
# 4          False           0       4   5211274     N   888968     100000

# %%
df_1281918 = df_glowpick [reviews ['user_id'] == '1281918']
df_1281918
# Out:
#                                                   contents  \
# 85901    시카가 여드름에 효능이 좋다해서 써봤는데 세안하고 닦아내는 용도로 사용중인데 괜찮아...
# 93439    커버력도 좋고 촉촉함도 있어서 쓰기 좋아요.\r\n쿠션타입이만 퍼프해서 사용가능해서...
# 112244   비싼 제품은 부담되어 저렴이버전 led마스크 찾던중 알게되어 구매했는데 선캡 쓴것처...
# 117820   펌핑해서 얼굴에 살살 바르면 거품이 올라오는데 톡톡톡 얼굴에 흡수시키고 나면 금방 ...
# 143698   벨벳형식이라 발색력도 좋지만 립글로즈처럼 끈적임이 없어서 좋아요.\r\n다만 건조함...
# 146287   여드름이 약간 있어서 사용중인데 냄새도 좋고 제형도 좋아요! 패키지도 들고 다니기 ...
# 169516   냄새도 좋고 성분도 좋은데 시간 지나면 끈적거림이 있어요. 흡수가 되는건지 조금 긴...
# 169594   휴대용 티슈타입 사용 중인데 정말 좋아요.\r\n특히 그날에 냄새때문에 민감할수 있...
# 182459   각질제거용으로 구매했어요.\r\n제가 쓰려고 구매했는데 아빠피부가 각질에 많아서 아...
# 187684   모공케어용으로 샀는데 모공케어 되는지는 잘모르겠어요.\r\n반이상 사용하였는데 아직...
# 203981   샬랑드파리 마스크팩을 처음구매해서 사용하다가 쿠션도 좋다는 후기가 있어서 구매해서 ...
# 250173   기존 다른 프라이머 사용할때는 프라이머 특유의 파우더리 느낌이 있었는데 포어블러프라...
# 250431   포어블러 프라이머 사용후 파운데이션 한후에 피부화장 마지막 단계에서 포어블러 파우더...
# 519568   발색력 짱인 제품이예요.\r\n펄도 은은하게 되어있고 입자가 작아서 과하지 않아요....
# 738701   파운데이션 바르기전에 사용하는데 은은하게 얼굴빛을 밝혀주고 광도 나게 해줘요.\r\...
# 781887   냄새에 민감해서 냉이 많은날이나 대자연 시작 되면 많이 걱정됬었는데 이거 사용한후로...
# 1033991  일본 여행가서 가져온 아인데 여행가서 휴대용으로 사용하긴 좋아요.\r\n저는 거품 ...
# 1044415  피지 있을때 사용하면 좋더라구요. 물 뿌려가면서 샤워할때 사용중이예요\r\n코옆은 ...
# 1301958  밤제형으로 되어있어 체온으로 녹여서 사용하는 제품 이였어요.\r\n오일과 밤의 장점...
# 1302052  피부 보호에 탁월한 효과가 있다고 해서 사용해봤습니다.\r\n습진에 유명하다고 해서...
# 1309455  하이라이터가 은은하게 사용 되어 좋아요.\r\n과하지 않은 펄들이 좋아요.\r\n베...
# 1311370  무기지차라고 해서 구매했는데 백탁현상이 심해서 얼굴이 회갈빛이 돌아요..\r\n성분...
# 1415524  발색도 좋았지만 다양한 색이 있어서 기분에 따라 사용가능 해서 좋았어요.\r\n물이...
# 1447731  에스**더 파운데이션 사용하다 입생로랑 파운데이션 좋다는 말에 사용해봤는데 커버력도...
# 1470180  일본여행가서 알게되어 사온아이인데 발색력도 좋고\r\n크기도 작아서 휴대하기도 좋아...
# 1525939  따로 향수를 안써도 될정도로 향도 오래가고 좋아요.\r\n향수 대용으로 머리에도 뿌...
# 1551223  향도 좋고 따로 씻을 필요없이 사용할수 있어 좋아요.\r\n머리 감고 나와서 말리기...
#
#                    created_at  rating  user_id  product_id  age  gender  \
# 85901    2019-06-19T12:15:05Z       4    11163        3761   27       0
# 93439    2019-06-19T00:00:59Z       4    11163        4010   27       0
# 112244   2019-06-23T01:36:50Z       4    11163        4911   27       0
# 117820   2019-06-19T12:48:16Z       4    11163        5204   27       0
# 143698   2019-07-05T21:17:29Z       4    11163        6203   27       0
# 146287   2019-06-18T12:55:59Z       4    11163        6311   27       0
# 169516   2019-06-18T12:52:57Z       3    11163        7333   27       0
# 169594   2019-07-07T12:16:25Z       5    11163        7338   27       0
# 182459   2019-06-19T00:26:45Z       4    11163        7964   27       0
# 187684   2019-06-18T13:00:15Z       3    11163        8210   27       0
# 203981   2019-06-18T12:40:55Z       4    11163        9006   27       0
# 250173   2019-07-10T23:42:57Z       5    11163       11397   27       0
# 250431   2019-07-10T23:59:07Z       4    11163       11398   27       0
# 519568   2019-06-19T12:51:24Z       4    11163       21348   27       0
# 738701   2019-06-19T12:11:19Z       4    11163       25412   27       0
# 781887   2019-06-19T12:18:25Z       5    11163       26450   27       0
# 1033991  2019-06-19T00:29:08Z       3    11163       32658   27       0
# 1044415  2019-06-23T01:39:56Z       4    11163       32914   27       0
# 1301958  2019-07-05T21:10:51Z       5    11163       41519   27       0
# 1302052  2019-07-07T11:54:46Z       4    11163       41521   27       0
# 1309455  2019-06-18T12:48:17Z       4    11163       41839   27       0
# 1311370  2019-06-19T12:07:01Z       2    11163       41910   27       0
# 1415524  2019-07-07T12:03:01Z       4    11163       45389   27       0
# 1447731  2019-06-19T00:06:30Z       4    11163       46555   27       0
# 1470180  2019-06-19T00:19:14Z       5    11163       47467   27       0
# 1525939  2019-06-19T12:30:29Z       5    11163       27831   27       0
# 1551223  2019-07-07T11:59:15Z       4    11163       37216   27       0
#
#          is_blinded is_closed is_inactivated  skin_type  \
# 85901           0.0     False          False          2
# 93439           0.0     False          False          2
# 112244          0.0     False          False          2
# 117820          0.0     False          False          2
# 143698          0.0     False          False          2
# 146287          0.0     False          False          2
# 169516          0.0     False          False          2
# 169594          0.0     False          False          2
# 182459          0.0     False          False          2
# 187684          0.0     False          False          2
# 203981          0.0     False          False          2
# 250173          0.0     False          False          2
# 250431          0.0     False          False          2
# 519568          0.0     False          False          2
# 738701          0.0     False          False          2
# 781887          0.0     False          False          2
# 1033991         0.0     False          False          2
# 1044415         0.0     False          False          2
# 1301958         0.0     False          False          2
# 1302052         0.0     False          False          2
# 1309455         0.0     False          False          2
# 1311370         0.0     False          False          2
# 1415524         0.0     False          False          2
# 1447731         0.0     False          False          2
# 1470180         0.0     False          False          2
# 1525939         0.0     False          False          2
# 1551223         0.0     False          False          2
#
#                                   title   volume     price  \
# 85901                       시카 리페어 필링패드      72p   15000.0
# 93439    씨앤티 마스터글램 (시즌2) [SPF50+/PA+++]     12ml   45000.0
# 112244                     코스메티 LED 마스크      1ea  219000.0
# 117820              볼륨 톡스 오리지널 펩타이드 에센스    100ml   99000.0
# 143698                     타투 끌레르 벨벳 틴트       4g   19000.0
# 146287                         끄렘 드 오로라     30ml   31800.0
# 169516                  앰플 드 오로라_113166     30ml   44800.0
# 169594                페미닌 클렌징 와입스 노멀 스킨     16ea    8000.0
# 182459                           지우개 패드     60ea   17000.0
# 187684                         끄렘 드 스텔라     30ml   31800.0
# 203981              쿠션 드 루나 프리미엄_116981      15g   39800.0
# 250173                       포어 블러 프라이머     25ml   12000.0
# 250431                        포어 블러 파우더      11g   15000.0
# 519568                        제미네이트 아이즈     6.7g   70000.0
# 738701           스킨 일루미네이션 [SPF30/PA++]     30ml   53000.0
# 781887                     시크릿러브 블랙에디션       5ml   39000.0
# 1033991                     뷰티 클리어 파우더   0.4g*32   21000.0
# 1044415                  초음파 에스테틱 워터필링기      1ea   79000.0
# 1301958                모이스트 플로랄 밤_86101     50ml   30000.0
# 1302052                        스킨파이버 젤리     100g   59000.0
# 1309455                        단델리온 트윙클       3g   43000.0
# 1311370            베리어선 끄렘 미네랄 [SPF50+]     50ml   35000.0
# 1415524               매트 앤 메탈 아이섀도우 팔레트      12g   58000.0
# 1447731          올아워 파운데이션 [SPF20/PA++]     25ml   79000.0
# 1470180                   브라운 섀이드 아이즈 N       3g   22000.0
# 1525939                 샹스 오 땅드르 헤어 미스트     35ml   64000.0
# 1551223                엔젤 모링가 LPP 트린트먼트     200g   18900.0
#
#                          brandName  idThirdCategory
# 85901                닥터에이지 (Dr.AG)            126.0
# 93439                         조성아™             31.0
# 112244                     아름다운연구소            255.0
# 117820               파이진 (PI.GENE)             17.0
# 143698             포렌코즈 (FORENCOS)             49.0
# 146287   샬랑드파리 (CHALLANS de PARIS)             18.0
# 169516   샬랑드파리 (CHALLANS de PARIS)             15.0
# 169594        썸머스이브 (summer's eve)            228.0
# 182459              셀리맥스 (celimax)            126.0
# 187684   샬랑드파리 (CHALLANS de PARIS)             21.0
# 203981   샬랑드파리 (CHALLANS de PARIS)             31.0
# 250173           이니스프리 (innisfree)             42.0
# 250431           이니스프리 (innisfree)             36.0
# 519568               루나솔 (LUNASOL)             75.0
# 738701             비디비치 (VIDIVICI)             89.0
# 781887                디오넬 (DIONEL)            246.0
# 1033991              수이사이 (suisai)            116.0
# 1044415              라벨르 (LABELLE)            258.0
# 1301958               마녀공장 (manyo)             19.0
# 1302052              블랑드 (BLANC D)             18.0
# 1309455             베네피트 (benefit)             81.0
# 1311370              유리아쥬 (URIAGE)            142.0
# 1415524                스틸라 (stila)             75.0
# 1447731                 입생로랑 (YSL)             30.0
# 1470180                 케이트 (KATE)             75.0
# 1525939                샤넬 (CHANEL)            200.0
# 1551223            보타미안 (botamian)            196.0

# %%
# user id가 1281918인 user 테스트
# train_1281918, test_1281918 = train_test_split (df_1281918, test_size = 0.8)


# train_model_input_1281918 = {name: train_1281918 [name] for name in feature_names}
test_model_input_1281918 = {name: df_1281918 [name] for name in feature_names}

pred_ans = model.predict (test_model_input_1281918, batch_size = 256)

print ("test RMSE", round (sqrt (mean_squared_error (df_1281918 [target].values, pred_ans)), 4))
# Out:
# test RMSE 0.5295

# %%
result_list = list (zip (pred_ans.tolist (), df_1281918 [target].values.tolist ()))
result_list
# Out:
# [([3.7571470737457275], [4]),
#  ([4.238088130950928], [4]),
#  ([4.079061031341553], [4]),
#  ([4.310779094696045], [4]),
#  ([3.6760456562042236], [4]),
#  ([3.5312931537628174], [4]),
#  ([3.5580692291259766], [3]),
#  ([4.386271953582764], [5]),
#  ([3.901275396347046], [4]),
#  ([3.7287116050720215], [3]),
#  ([4.327513217926025], [4]),
#  ([3.994749069213867], [5]),
#  ([4.380995273590088], [4]),
#  ([4.267673015594482], [4]),
#  ([4.1621246337890625], [4]),
#  ([4.618373394012451], [5]),
#  ([3.9829258918762207], [3]),
#  ([4.137250900268555], [4]),
#  ([3.918311595916748], [5]),
#  ([4.34718132019043], [4]),
#  ([4.234959125518799], [4]),
#  ([1.983639121055603], [2]),
#  ([4.431247234344482], [4]),
#  ([4.554099082946777], [4]),
#  ([4.065104007720947], [5]),
#  ([4.283544063568115], [5]),
#  ([4.280738830566406], [4])]

# %%
def get_real_user_score (user_id, feature_names = feature_names):
    user_df = df_glowpick [reviews ['user_id'] == str (user_id)]
    user_model_input = {name: user_df [name] for name in feature_names}

    pred_ans = model.predict (user_model_input, batch_size = 256)

    print ("test RMSE", round (sqrt (mean_squared_error (user_df [target].values, pred_ans)), 4))
    print ('\nReal Score', list (zip (pred_ans.tolist (), user_df [target].values.tolist ())))

# %%
reviews.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    is_evaluation  like_count  rating review_id state  user_id product_id
# 0          False           0       3   5416271     N   119763     100000
# 1          False           0       4   5340616     N   338669     100000
# 2          False           0       3   5228598     N    24862     100000
# 3          False           0       4   5225359     N  1331797     100000
# 4          False           0       4   5211274     N   888968     100000

# %%
get_real_user_score (119763, feature_names)
# Out:
# test RMSE 1.0041
#
# Real Score [([3.3647308349609375], [3]), ([3.7861568927764893], [4]), ([3.0997161865234375], [2]), ([3.0175468921661377], [4]), ([3.5525147914886475], [3]), ([3.348318099975586], [4]), ([3.970305919647217], [3]), ([3.7553493976593018], [4]), ([3.9729838371276855], [3]), ([4.241269588470459], [5]), ([3.4355404376983643], [4]), ([3.0436720848083496], [3]), ([4.2480010986328125], [5]), ([4.303683757781982], [4]), ([3.777149200439453], [4]), ([4.150819778442383], [2]), ([3.5279078483581543], [4]), ([3.5358896255493164], [4]), ([4.005305290222168], [5]), ([3.414149761199951], [2]), ([3.7169651985168457], [3]), ([3.357083320617676], [1]), ([3.471755266189575], [4]), ([3.5525150299072266], [5]), ([3.657834529876709], [3]), ([3.0594420433044434], [2]), ([4.190270900726318], [4]), ([3.4755496978759766], [5]), ([3.9149296283721924], [5]), ([3.7697789669036865], [5]), ([3.1234798431396484], [3]), ([3.7231833934783936], [3]), ([3.498690128326416], [2]), ([4.1205949783325195], [4]), ([4.115872383117676], [4]), ([3.243792772293091], [3]), ([4.326183319091797], [5]), ([3.3199939727783203], [4]), ([4.157419204711914], [5]), ([3.3366050720214844], [3]), ([3.9183545112609863], [4]), ([3.3476812839508057], [2]), ([4.044480800628662], [4]), ([3.9692368507385254], [3]), ([3.5525147914886475], [5]), ([3.6384353637695312], [5]), ([4.027275562286377], [5]), ([3.816084623336792], [4]), ([3.8071181774139404], [5]), ([2.8333661556243896], [1]), ([3.9931881427764893], [5]), ([3.291515588760376], [4]), ([4.3396382331848145], [5]), ([3.6230273246765137], [5]), ([3.7731897830963135], [2]), ([4.267474174499512], [4]), ([3.908003330230713], [4]), ([4.2051591873168945], [5]), ([2.548213481903076], [3]), ([3.2235124111175537], [5]), ([3.6873393058776855], [5]), ([3.860675811767578], [5]), ([3.1337199211120605], [2]), ([3.8480191230773926], [5]), ([4.141228675842285], [5]), ([4.013797283172607], [3]), ([4.248189926147461], [4]), ([4.4954071044921875], [5]), ([4.169983386993408], [4]), ([3.5592358112335205], [3]), ([3.405258893966675], [3]), ([3.775571823120117], [4]), ([3.8626482486724854], [5]), ([4.231682300567627], [5]), ([3.0430331230163574], [4]), ([4.291628837585449], [5]), ([3.408392906188965], [3]), ([3.614105224609375], [4]), ([3.657970905303955], [5]), ([3.7486987113952637], [4]), ([3.910552740097046], [3]), ([3.2046828269958496], [4]), ([3.89929461479187], [3]), ([3.624350070953369], [3]), ([3.641662120819092], [3]), ([3.6090123653411865], [4]), ([3.3743045330047607], [4]), ([3.677402973175049], [4]), ([4.092187404632568], [3]), ([3.981367349624634], [5]), ([3.5709900856018066], [2]), ([3.0316951274871826], [4]), ([3.257086992263794], [2]), ([3.485651969909668], [5]), ([3.995964288711548], [5]), ([3.705185890197754], [5]), ([3.929781436920166], [4]), ([3.841334819793701], [5]), ([3.0799691677093506], [1]), ([3.869966506958008], [5]), ([3.3937020301818848], [5]), ([3.90865159034729], [4]), ([3.420091390609741], [5]), ([3.889566421508789], [4]), ([4.2632622718811035], [5]), ([4.229066371917725], [1]), ([3.397125244140625], [3]), ([3.314607620239258], [2]), ([4.064380645751953], [5]), ([4.3541951179504395], [4]), ([3.5366740226745605], [4]), ([4.145319938659668], [5]), ([4.189903259277344], [4]), ([3.791808605194092], [4]), ([3.831163167953491], [2]), ([4.4252519607543945], [4]), ([3.8111937046051025], [2]), ([4.272007465362549], [4]), ([3.9767980575561523], [3]), ([3.8926496505737305], [2]), ([3.281416177749634], [3]), ([3.6733736991882324], [4]), ([3.6409125328063965], [4]), ([4.46565055847168], [5]), ([4.000324726104736], [3]), ([3.8705801963806152], [5]), ([3.7687721252441406], [4]), ([3.5525147914886475], [4])]

# %%
df_glowpick [reviews ['user_id'] == '119763']
# Out:
#                                                   contents  \
# 0        티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...
# 5734     살짝 무게감 있는 질감의 수분 에센스가 적셔져 있는 마스크팩입니다. 시트의 밀착력이...
# 5738     사용해 본 샤이닝 이펙트 마스크 3종 중 가장 별로. 일단 시트가 에센스를 잘 머금...
# 5741     에멀전 타입 에센스 마스크팩으로 수분 충전 보다는 영양감, 무게감 있는 보습감을 주...
# 5764     시술 후 모발을 위한 마카다미아 오일 라인의 컨디셔너. 무거운 제형이지 않을까 생각...
# ...                                                    ...
# 1550838  베이스 트리트먼트에 ppt를 섞어 쓰는 제품입니다. 모방 상태에 따라 ppt 양을 ...
# 1553885  코튼패드라는 이름이지만 사실 코튼은 아니고 레이온과 펄프 혼방 재질인 스펀지형 화장...
# 1561681  청포도와 키위향이 상큼하게 잘 어우러저 손을 씻을 때마다 기분이 좋아지는 핸드워시예...
# 1561809  같은 라인 옐로우 그린에 비해 만족도는 살짝 떨어져요. 풍성한 거품이나 뽀득한 세정...
# 1561880  많이들 사용하시는 아이깨끗해 기본 제품과 큰 차이는 없고, 좀 더 플로럴한 향이 가...
#
#                    created_at  rating  user_id  product_id  age  gender  \
# 0        2020-04-30T02:12:36Z       3     7216           0   32       0
# 5734     2018-12-12T10:01:10Z       4     7216         191   32       0
# 5738     2019-03-11T16:34:51Z       2     7216         193   32       0
# 5741     2019-02-16T13:34:23Z       4     7216         195   32       0
# 5764     2020-02-25T17:45:48Z       3     7216         201   32       0
# ...                       ...     ...      ...         ...  ...     ...
# 1550838  2018-11-22T06:43:40Z       5     7216         311   32       0
# 1553885  2020-05-02T14:36:22Z       3     7216       43738   32       0
# 1561681  2020-03-01T04:10:33Z       5     7216       42968   32       0
# 1561809  2020-03-01T04:12:13Z       4     7216       42969   32       0
# 1561880  2019-08-27T12:46:13Z       4     7216       11620   32       0
#
#          is_blinded is_closed is_inactivated  skin_type  \
# 0               0.0     False          False          2
# 5734            0.0     False          False          2
# 5738            0.0     False          False          2
# 5741            0.0     False          False          2
# 5764            0.0     False          False          2
# ...             ...       ...            ...        ...
# 1550838         0.0     False          False          2
# 1553885         0.0     False          False          2
# 1561681         0.0     False          False          2
# 1561809         0.0     False          False          2
# 1561880         0.0     False          False          2
#
#                               title volume    price               brandName  \
# 0                 티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0       해피바스 (HAPPY BATH)
# 5734     스텝솔루션 샤이닝 이펙트 아쿠아토닝 진주 마스크   25ml   3000.0       리더스코스메틱 (LEADERS)
# 5738     스텝솔루션 샤이닝 이펙트 안티 링클 진주 마스크   25ml   3000.0       리더스코스메틱 (LEADERS)
# 5741       스텝솔루션 샤이닝 이펙트 리프팅 진주 마스크   25ml   3000.0       리더스코스메틱 (LEADERS)
# 5764              리페어링 마카다미아오일 컨디셔너  250ml  12600.0    마크앤써니 (MARC ANTHONY)
# ...                             ...    ...      ...                     ...
# 1550838          커스텀 케어 01 헤어 트리트먼트  230ml  48000.0  아우라 아듀라 (Aura Adllura)
# 1553885                  1/2 코튼 화장솜   80ea   3000.0          아리따움 (ARITAUM)
# 1561681      쥬스 스무디 버블 핸드 워시 옐로우 그린  250ml   6500.0       해피바스 (HAPPY BATH)
# 1561809          쥬스 스무디 버블 핸드 워시 레드  250ml   6500.0       해피바스 (HAPPY BATH)
# 1561880      아이깨끗해 향균 폼 핸드솝 [허니플라워]  250ml      0.0              라이온 (LION)
#
#          idThirdCategory
# 0                  112.0
# 5734               131.0
# 5738               132.0
# 5741               132.0
# 5764               189.0
# ...                  ...
# 1550838            196.0
# 1553885            109.0
# 1561681            166.0
# 1561809            166.0
# 1561880            166.0
#
# [128 rows x 16 columns]

# %%
df_glowpick.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    rating  user_id  product_id  age  gender  is_blinded is_closed  \
# 0       3     7216           0   32       0         0.0     False
# 1       4    22803           0   34       0         0.0     False
# 2       3    19263           0   24       0         0.0     False
# 3       4    13371           0   16       0         0.0     False
# 4       4    68326           0   29       0         0.0     False
#
#   is_inactivated  skin_type              title volume    price  \
# 0          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 1          False          3  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 2          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 3          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
# 4          False          2  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0
#
#            brandName  idThirdCategory
# 0  해피바스 (HAPPY BATH)            112.0
# 1  해피바스 (HAPPY BATH)            112.0
# 2  해피바스 (HAPPY BATH)            112.0
# 3  해피바스 (HAPPY BATH)            112.0
# 4  해피바스 (HAPPY BATH)            112.0

# %%
df_glowpick [reviews ['user_id'] == '119763']
