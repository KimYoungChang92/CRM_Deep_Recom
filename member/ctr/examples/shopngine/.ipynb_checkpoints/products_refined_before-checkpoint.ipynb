# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

import common
from common import FILE_PATH
from common import MODEL_PATH

st = sns.axes_style("whitegrid")
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})

plt.rcParams ['font.family'] = 'NanumGothic'

import warnings
warnings.filterwarnings("ignore")

# %%
# 리뷰 정보 읽어들이기
reviews = pd.read_csv (FILE_PATH + 'reviews.txt', sep = ',', 
                       dtype = {'review_id' : 'object', 'user_id' : 'object', 'product_id' : 'object'})
reviews.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    is_evaluation  like_count  rating review_id state  user_id product_id
# 0          False           0       3   5416271     N   119763     100000
# 1          False           0       4   5340616     N   338669     100000
# 2          False           0       3   5228598     N    24862     100000
# 3          False           0       4   5225359     N  1331797     100000
# 4          False           0       4   5211274     N   888968     100000

# %%
reviews.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1574817 entries, 0 to 1574816
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   contents       1574817 non-null  object
#  1   created_at     1574817 non-null  object
#  2   is_evaluation  1574817 non-null  bool
#  3   like_count     1574817 non-null  int64
#  4   rating         1574817 non-null  int64
#  5   review_id      1574817 non-null  object
#  6   state          1574817 non-null  object
#  7   user_id        1574817 non-null  object
#  8   product_id     1574817 non-null  object
# dtypes: bool(1), int64(2), object(6)
# memory usage: 97.6+ MB

# %%
reviews.isnull ().sum ()
# Out:
# contents         0
# created_at       0
# is_evaluation    0
# like_count       0
# rating           0
# review_id        0
# state            0
# user_id          0
# product_id       0
# dtype: int64

# %%
users = pd.read_csv (FILE_PATH + 'users.txt', sep = ',', dtype = {'user_id' : 'object'})
users.head ()
# Out:
#     age  birth_year                     email gender  is_blinded  is_closed  \
# 0  31.0      1990.0          yhcu88@naver.com      f           0      False
# 1  33.0      1988.0    winwinanna@hanmail.net      f           0      False
# 2  37.0      1984.0  dmswjddlskfk@hanmail.net      f           0      False
# 3  32.0      1989.0         deer402@naver.com      f           0      False
# 4  26.0      1995.0         kkr3348@naver.com      f           0      False
#
#    is_inactivated     nickname  \
# 0           False          희뷰리
# 1           False       소극적인뷰터
# 2           False  greengables
# 3            True          백비송
# 4           False         초코감귤
#
#                                        profile_image   rank  review_count  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  27347            44
# 1                                                NaN  41582            15
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...    946           375
# 3  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  43404            29
# 4  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...   9386            97
#
#   skin_type  user_id
# 0       복합성  1281918
# 1        건성  1255686
# 2        지성   631689
# 3        건성  1188087
# 4       복합성   632220

# %%
users.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76490 entries, 0 to 76489
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             76489 non-null  float64
#  1   birth_year      76489 non-null  float64
#  2   email           76490 non-null  object
#  3   gender          76490 non-null  object
#  4   is_blinded      76490 non-null  int64
#  5   is_closed       76490 non-null  bool
#  6   is_inactivated  76490 non-null  bool
#  7   nickname        76489 non-null  object
#  8   profile_image   44893 non-null  object
#  9   rank            76490 non-null  int64
#  10  review_count    76490 non-null  int64
#  11  skin_type       76490 non-null  object
#  12  user_id         76490 non-null  object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 6.6+ MB

# %%
users.describe ()
# Out:
#                 age    birth_year  is_blinded          rank  review_count
# count  76456.000000  76456.000000     76456.0  7.645600e+04  76456.000000
# mean      25.250118   1995.749882         0.0  6.909060e+04     41.476823
# std        5.984109      5.984109         0.0  5.044060e+05     56.878904
# min        2.000000   1932.000000         0.0  1.000000e+00    -46.000000
# 25%       21.000000   1993.000000         0.0  1.853600e+04     10.000000
# 50%       25.000000   1996.000000         0.0  3.840400e+04     26.000000
# 75%       28.000000   2000.000000         0.0  6.279600e+04     51.000000
# max       89.000000   2019.000000         0.0  9.999999e+06   2003.000000

# %%
users ['age'].mean (axis = 0)
# Out:
# 25.352821974401547

# %%
# 나이와 생년 결측치를 평균값으로 치환
user_age_mean = users ['age'].mean (axis = 0)
user_birth_mean = users ['birth_year'].mean (axis = 0)

users ['age'].fillna (user_age_mean, inplace = True)
users ['birth_year'].fillna (user_birth_mean, inplace = True)

# %%
users.head ()
# Out:
#     age  birth_year                     email gender  is_blinded  is_closed  \
# 0  31.0      1990.0          yhcu88@naver.com      f           0      False
# 1  33.0      1988.0    winwinanna@hanmail.net      f           0      False
# 2  37.0      1984.0  dmswjddlskfk@hanmail.net      f           0      False
# 3  32.0      1989.0         deer402@naver.com      f           0      False
# 4  26.0      1995.0         kkr3348@naver.com      f           0      False
#
#    is_inactivated     nickname  \
# 0           False          희뷰리
# 1           False       소극적인뷰터
# 2           False  greengables
# 3            True          백비송
# 4           False         초코감귤
#
#                                        profile_image   rank  review_count  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  27347            44
# 1                                                NaN  41582            15
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...    946           375
# 3  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  43404            29
# 4  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...   9386            97
#
#   skin_type  user_id
# 0       복합성  1281918
# 1        건성  1255686
# 2        지성   631689
# 3        건성  1188087
# 4       복합성   632220

# %%
users.isnull ().sum ()
# Out:
# age                   0
# birth_year            0
# email                 0
# gender                0
# is_blinded            0
# is_closed             0
# is_inactivated        0
# nickname              1
# profile_image     31597
# rank                  0
# review_count          0
# skin_type             0
# user_id               0
# dtype: int64

# %%
products = pd.read_csv (FILE_PATH + 'products.txt', sep = ',', dtype = {'id' : 'object'})
products.rename (columns = {'id' : 'product_id'}, inplace = True)


products.head ()
# Out:
#   product_id rank                 title volume    price reviewCnt ratingAvg  \
# 0     108711    5          코스메티 LED 마스크    1ea   219000         4      3.75
# 1     118971    6               LED 마스크    1ea   149000         2       4.0
# 2     118819    7  디쎄 1.0 LED 마스크 [업무용]    1ea  1320000         1       5.0
# 3      90929    8            LED 리얼 마스크    1ea   198000         1       4.0
# 4     127206    9     인텐시브 LED 마스크 프리미엄    1ea  1517100         1       5.0
#
#                                           productImg isDiscontinue rankChange  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 1  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 3  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 4  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
#
#   rankChangeType                                              brand  \
# 0           show  {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...
# 1           show  {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...
# 2           show  {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...
# 3           show  {'idBrand': None, 'brandTitle': '솔루미에스테 (SOLLU...
# 4           show  {'idBrand': None, 'brandTitle': '엘리닉 (L Linic)...
#
#            goodsInfo
# 0  {'goodsCount': 0}
# 1  {'goodsCount': 0}
# 2  {'goodsCount': 0}
# 3  {'goodsCount': 0}
# 4  {'goodsCount': 0}

# %%
products.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89059 entries, 0 to 89058
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      89059 non-null  object
#  1   rank            89059 non-null  object
#  2   title           89059 non-null  object
#  3   volume          89059 non-null  object
#  4   price           89036 non-null  object
#  5   reviewCnt       89059 non-null  object
#  6   ratingAvg       89059 non-null  object
#  7   productImg      89058 non-null  object
#  8   isDiscontinue   89059 non-null  object
#  9   rankChange      89059 non-null  object
#  10  rankChangeType  89059 non-null  object
#  11  brand           89059 non-null  object
#  12  goodsInfo       89059 non-null  object
# dtypes: object(13)
# memory usage: 8.8+ MB

# %%
products.isnull ().sum ()
# Out:
# product_id         0
# rank               0
# title              0
# volume             0
# price             23
# reviewCnt          0
# ratingAvg          0
# productImg         1
# isDiscontinue      0
# rankChange         0
# rankChangeType     0
# brand              0
# goodsInfo          0
# dtype: int64

# %%
product_categories = pd.read_csv (FILE_PATH + 'product_categories.txt', sep = ',')
product_categories.head ()
# Out:
#   firstCategoryText  idFirstCategory  idSecondCategory  idThirdCategory  \
# 0             프래그런스               15                83              246
# 1               클렌징                7                32              112
# 2             립메이크업                3                15               50
# 3             립메이크업                3                17               54
# 4            아이메이크업                4                22               75
#
#   secondCategoryText thirdCategoryText product_id
# 0                 향수              여성향수      10000
# 1             페이셜클렌저              클렌징폼     100000
# 2             립틴트/라커           글로시/젤틴트       1030
# 3               립글로스              립글로스     100002
# 4              아이섀도우             아이팔레트      88268

# %%
product_categories ['product_id'].value_counts ()
# Out:
# 3754      38
# 1558      26
# 22223     23
# 74532     19
# 90430     19
#           ..
# 54873      1
# 112989     1
# 123371     1
# 26059      1
# 99251      1
# Name: product_id, Length: 79227, dtype: int64

# %%
product_categories [product_categories ['product_id'] == '3754'].sort_values (by = 'idFirstCategory')
# Out:
#       firstCategoryText  idFirstCategory  idSecondCategory  idThirdCategory  \
# 2204               스킨케어                1                 4               23
# 78835              스킨케어                1                 4               23
# 75295              스킨케어                1                 3               16
# 72036              스킨케어                1                 3               16
# 69040              스킨케어                1                 4               23
# 64636              스킨케어                1                 4               23
# 53889              스킨케어                1                 4               23
# 53868              스킨케어                1                 4               23
# 44249              스킨케어                1                 3               16
# 42016              스킨케어                1                 4               23
# 41819              스킨케어                1                 3               16
# 40114              스킨케어                1                 4               23
# 31578              스킨케어                1                 4               23
# 42005              스킨케어                1                 3               16
# 82141              스킨케어                1                 4               23
# 15083              스킨케어                1                 3               16
# 12970              스킨케어                1                 3               16
# 4713               스킨케어                1                 3               16
# 9185               스킨케어                1                 4               23
# 25293              스킨케어                1                 4               23
# 50304           페이스메이크업                2                 7               31
# 69650           페이스메이크업                2                 7               31
# 33669            아이메이크업                4                22               71
# 17899            아이메이크업                4                22               71
# 14952            아이메이크업                4                22               71
# 74143            아이메이크업                4                21               69
# 71558            아이메이크업                4                21               69
# 66733            아이메이크업                4                22               71
# 6898             아이메이크업                4                21               69
# 3284              마스크/팩                8                37              131
# 21964             마스크/팩                8                38              134
# 8749              마스크/팩                8                38              134
# 9933              마스크/팩                8                37              131
# 62175             마스크/팩                8                37              131
# 52252             배쓰&바디               10                49              155
# 80998             배쓰&바디               10                49              155
# 3112              배쓰&바디               10                49              155
# 68116             배쓰&바디               10                49              153
#
#       secondCategoryText thirdCategoryText product_id
# 2204                  크림              아이크림       3754
# 78835                 크림              아이크림       3754
# 75295             에센스/세럼          브라이트닝에센스       3754
# 72036             에센스/세럼          브라이트닝에센스       3754
# 69040                 크림              아이크림       3754
# 64636                 크림              아이크림       3754
# 53889                 크림              아이크림       3754
# 53868                 크림              아이크림       3754
# 44249             에센스/세럼          브라이트닝에센스       3754
# 42016                 크림              아이크림       3754
# 41819             에센스/세럼          브라이트닝에센스       3754
# 40114                 크림              아이크림       3754
# 31578                 크림              아이크림       3754
# 42005             에센스/세럼          브라이트닝에센스       3754
# 82141                 크림              아이크림       3754
# 15083             에센스/세럼          브라이트닝에센스       3754
# 12970             에센스/세럼          브라이트닝에센스       3754
# 4713              에센스/세럼          브라이트닝에센스       3754
# 9185                  크림              아이크림       3754
# 25293                 크림              아이크림       3754
# 50304              파운데이션           쿠션파운데이션       3754
# 69650              파운데이션           쿠션파운데이션       3754
# 33669              아이섀도우             싱글섀도우       3754
# 17899              아이섀도우             싱글섀도우       3754
# 14952              아이섀도우             싱글섀도우       3754
# 74143              아이브로우          리퀴드아이브로우       3754
# 71558              아이브로우          리퀴드아이브로우       3754
# 66733              아이섀도우             싱글섀도우       3754
# 6898               아이브로우          리퀴드아이브로우       3754
# 3284               시트마스크          브라이트닝마스크       3754
# 21964             페이스마스크             워시오프팩       3754
# 8749              페이스마스크             워시오프팩       3754
# 9933               시트마스크          브라이트닝마스크       3754
# 62175              시트마스크          브라이트닝마스크       3754
# 52252            바디로션/크림              바디버터       3754
# 80998            바디로션/크림              바디버터       3754
# 3112             바디로션/크림              바디버터       3754
# 68116            바디로션/크림              바디로션       3754

# %%
product_categories.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88756 entries, 0 to 88755
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   firstCategoryText   88756 non-null  object
#  1   idFirstCategory     88756 non-null  int64
#  2   idSecondCategory    88756 non-null  int64
#  3   idThirdCategory     88756 non-null  int64
#  4   secondCategoryText  88756 non-null  object
#  5   thirdCategoryText   88704 non-null  object
#  6   product_id          88756 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 4.7+ MB

# %%
product_categories.isnull ().sum ()
# Out:
# firstCategoryText      0
# idFirstCategory        0
# idSecondCategory       0
# idThirdCategory        0
# secondCategoryText     0
# thirdCategoryText     52
# product_id             0
# dtype: int64

# %% [markdown]
# ### 전처리

# %% [markdown]
# #### products

# %%
def delete_dupli_under_review_cnt (df, count = 50):
    df_dupl = df.groupby ('title').filter (lambda x : len (x) > 2)

    # 리뷰수가 50보다 작은 row는 삭제할 것임
    df_dupl = df_dupl [df_dupl ['reviewCnt'] < count]

    return df_dupl ['product_id'].values.tolist ()

# %%
# 상품명에서 'title' 이란 잘못된 값이 들어가있어서 해당 row를 빼고 새로운 데이터프레임 생성
products_df = products [products ['title'] != 'title']
products_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88774 entries, 0 to 89058
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      88774 non-null  object
#  1   rank            88774 non-null  object
#  2   title           88774 non-null  object
#  3   volume          88774 non-null  object
#  4   price           88751 non-null  object
#  5   reviewCnt       88774 non-null  object
#  6   ratingAvg       88774 non-null  object
#  7   productImg      88773 non-null  object
#  8   isDiscontinue   88774 non-null  object
#  9   rankChange      88774 non-null  object
#  10  rankChangeType  88774 non-null  object
#  11  brand           88774 non-null  object
#  12  goodsInfo       88774 non-null  object
# dtypes: object(13)
# memory usage: 9.5+ MB

# %%
products_df.head ()
# Out:
#   product_id rank                 title volume    price reviewCnt ratingAvg  \
# 0     108711    5          코스메티 LED 마스크    1ea   219000         4      3.75
# 1     118971    6               LED 마스크    1ea   149000         2       4.0
# 2     118819    7  디쎄 1.0 LED 마스크 [업무용]    1ea  1320000         1       5.0
# 3      90929    8            LED 리얼 마스크    1ea   198000         1       4.0
# 4     127206    9     인텐시브 LED 마스크 프리미엄    1ea  1517100         1       5.0
#
#                                           productImg isDiscontinue rankChange  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 1  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 3  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 4  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
#
#   rankChangeType                                              brand  \
# 0           show  {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...
# 1           show  {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...
# 2           show  {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...
# 3           show  {'idBrand': None, 'brandTitle': '솔루미에스테 (SOLLU...
# 4           show  {'idBrand': None, 'brandTitle': '엘리닉 (L Linic)...
#
#            goodsInfo
# 0  {'goodsCount': 0}
# 1  {'goodsCount': 0}
# 2  {'goodsCount': 0}
# 3  {'goodsCount': 0}
# 4  {'goodsCount': 0}

# %%
import ast

# 딕셔너리처럼 생긴 스트링 타입 brand 컬럼에서 brandTtile을 가져와서 brandName 이라는 컬럼을 생성
products_df ['brandName'] = products_df ['brand'].apply (lambda brand : ast.literal_eval (brand) ['brandTitle'])

# %%
# rank 와 reviewCnt 형변환. object to int64
int_cols = ['rank', 'reviewCnt']
float_cols = ['price', 'ratingAvg']

products_df [int_cols] = products_df [int_cols].astype ('int')
products_df [float_cols] = products_df [float_cols].astype ('float')

products_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88774 entries, 0 to 89058
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      88774 non-null  object
#  1   rank            88774 non-null  int64
#  2   title           88774 non-null  object
#  3   volume          88774 non-null  object
#  4   price           88751 non-null  float64
#  5   reviewCnt       88774 non-null  int64
#  6   ratingAvg       88774 non-null  float64
#  7   productImg      88773 non-null  object
#  8   isDiscontinue   88774 non-null  object
#  9   rankChange      88774 non-null  object
#  10  rankChangeType  88774 non-null  object
#  11  brand           88774 non-null  object
#  12  goodsInfo       88774 non-null  object
#  13  brandName       88774 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 10.2+ MB

# %%
del_id_list = delete_dupli_under_review_cnt (products_df)

len (del_id_list)
# Out:
# 1355

# %%
products_refined = products_df [~products_df ['product_id'].isin (del_id_list)]
products_refined.head ()
# Out:
#   product_id  rank                 title volume      price  reviewCnt  \
# 0     108711     5          코스메티 LED 마스크    1ea   219000.0          4
# 1     118971     6               LED 마스크    1ea   149000.0          2
# 2     118819     7  디쎄 1.0 LED 마스크 [업무용]    1ea  1320000.0          1
# 3      90929     8            LED 리얼 마스크    1ea   198000.0          1
# 4     127206     9     인텐시브 LED 마스크 프리미엄    1ea  1517100.0          1
#
#    ratingAvg                                         productImg isDiscontinue  \
# 0       3.75  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 2       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 3       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 4       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#   rankChange rankChangeType  \
# 0          0           show
# 1          0           show
# 2          0           show
# 3          0           show
# 4          0           show
#
#                                                brand          goodsInfo  \
# 0  {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...  {'goodsCount': 0}
# 1  {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...  {'goodsCount': 0}
# 2  {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...  {'goodsCount': 0}
# 3  {'idBrand': None, 'brandTitle': '솔루미에스테 (SOLLU...  {'goodsCount': 0}
# 4  {'idBrand': None, 'brandTitle': '엘리닉 (L Linic)...  {'goodsCount': 0}
#
#                 brandName
# 0                 아름다운연구소
# 1           에끌레어 (eclair)
# 2     닥터슈라클 (Dr.Ceuracle)
# 3  솔루미에스테 (SOLLUME ESTHE)
# 4           엘리닉 (L Linic)

# %%
print (len (products_df) - len (del_id_list))
print (len (products_refined))
# Out:
# 87419
# 87419

# %%
products_refined.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87419 entries, 0 to 89058
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      87419 non-null  object
#  1   rank            87419 non-null  int64
#  2   title           87419 non-null  object
#  3   volume          87419 non-null  object
#  4   price           87396 non-null  float64
#  5   reviewCnt       87419 non-null  int64
#  6   ratingAvg       87419 non-null  float64
#  7   productImg      87418 non-null  object
#  8   isDiscontinue   87419 non-null  object
#  9   rankChange      87419 non-null  object
#  10  rankChangeType  87419 non-null  object
#  11  brand           87419 non-null  object
#  12  goodsInfo       87419 non-null  object
#  13  brandName       87419 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 10.0+ MB

# %%
(products_refined ['title'].value_counts () > 2).index
# Out:
# Index(['모이스춰라이징 로션', '화산송이 모공 폼', '블러쉬', '올 어라운드 세이프 블록 에센스 선 [SPF45/PA+++]',
#        '메이크업 베이스', '라이스 마스크 워시 오프', '닥터지움 올 클리어 버블 클렌저', '아쿠아파워 클렌저',
#        '아메리칸 크림', '히아루론산 토너',
#        ...
#        '레그 앤 바디 왁스스트립', '글로우 바이 제이로 우먼 오드뚜왈렛', 'S.S 크림',
#        '하이드라라이프 유쓰 에센셜 하이드레이팅 클렌징 폼 ', '모이스처 그로잉 세럼', '꽁포르 익스트렘므 쑤엥 드 주르',
#        '트루 매트 립 플루이드', '크리미 매트 립칼라', '물광 골든 코쿤 핸드크림 블랙',
#        '미네랄 핸드크림 - 칵투스 & 핑크페퍼'],
#       dtype='object', length=86056)

# %%
products_refined ['title'].value_counts () > 2
# Out:
# 모이스춰라이징 로션                            True
# 화산송이 모공 폼                             True
# 블러쉬                                   True
# 올 어라운드 세이프 블록 에센스 선 [SPF45/PA+++]     True
# 메이크업 베이스                              True
#                                      ...
# 꽁포르 익스트렘므 쑤엥 드 주르                    False
# 트루 매트 립 플루이드                         False
# 크리미 매트 립칼라                           False
# 물광 골든 코쿤 핸드크림 블랙                     False
# 미네랄 핸드크림 - 칵투스 & 핑크페퍼                False
# Name: title, Length: 86056, dtype: bool

# %%
df_prod_ref_counts = products_refined ['title'].value_counts().to_frame()

df_prod_ref_counts [df_prod_ref_counts ['title'] > 1]
# Out:
#                                    title
# 모이스춰라이징 로션                             3
# 화산송이 모공 폼                              3
# 블러쉬                                    3
# 올 어라운드 세이프 블록 에센스 선 [SPF45/PA+++]      3
# 메이크업 베이스                               3
# ...                                  ...
# 휘핑 클렌징 폼                               2
# 청광 마린 진주 모이스처 트랜스 포밍 클레이 펄             2
# 센스티브 브러쉬 마스카라                          2
# 프리미엄 골드 콜라겐 토너                         2
# 리파이닝 컬러보니 브로우 마스카라                     2
#
# [1358 rows x 1 columns]

# %%
duplication_title_list = df_prod_ref_counts [df_prod_ref_counts ['title'] > 1].index.tolist()

# %%
df_prod_ref_counts [df_prod_ref_counts ['title'] > 1].sum ()
# Out:
# title    2721
# dtype: int64

# %%
# Out:
# 1358

# %%
print (duplication_title_list)
# Out:
# ['모이스춰라이징 로션', '화산송이 모공 폼', '블러쉬', '올 어라운드 세이프 블록 에센스 선 [SPF45/PA+++]', '메이크업 베이스', '라이스 마스크 워시 오프', '닥터지움 올 클리어 버블 클렌저', '아쿠아파워 클렌저', '아메리칸 크림', '히아루론산 토너', '내추럴 허니 마스크 시트', '티트리 클렌징 젤', '앰플 드 오로라', '샤워젤', '아트 콜라겐 젤리 하이드로겔 마스크', '프리미엄 블랙헤드 O2 버블 모공팩', '프라임 프라이머 피니쉬 팩트', '컨투어링 브러쉬', '크리미 파운데이션 N [SPF28/PA++]', '오이 클렌징 티슈', '수딩 클렌징 오일', '젤라이크 립', '렛 더 굿 타임즈 롤', '모이스트 업 수퍼 히아루론 크림', '라즈베리 헤어 식초', '수딩젤 로션', '선셋 프루츠 퍼퓸 바디워시', '무빙러버 에어 라이즈', '마일드 폼 클렌저', '퍼펙트 워터리 오일', '에스테틱 골드 매니큐어', '화이트닝 톤업 크림', '프레쉬 파머시', '비자 트러블 스팟 에센스', '스위트 아몬드 오일', '딥 모이스트 로션', '에너자이징 샴푸', '베이비 바디로션', '울트라슬림 중형', '금설 기윤 에센스', '플로리아 화이트닝 꽃잎 토너', '모이스처라이징 바디 워시', '맘앤트윈스 클렌저', '오프레시 딥 허벌 스캘프 앤 헤어팩', '핑크 그레이프후룻 바디 버터', '로즈 앱솔루트 아이 크림', '허브 미스트', '블랙슈가 마스크 워시 오프', '휴대용 미니고데기', '더마클리어 마이크로 워터', '아이펜슬', '4GF 아이래쉬 앰플', '어반 에코 하라케케 프레쉬 토너', '망고 오 드 뚜왈렛', '스킨로션', '드림 베이스', '콜라겐 리프트업 밴드', '실크 블로썸 코롱', '쥬얼라이트 동안 애교살 메이커', '워셔블 클렌징 밀크', '올인원 텐 섹', '16 티앤쥐', '갈락토미세스 아이크림', '스칼프 리밸런싱 트리트먼트', '바디 스크럽', '톡톡 페이셜 선팩트 [SPF43/PA+++]', '오토 아이브로우', '모이스처라이징 에멀젼', '슬라이스 마스크 시트(토마토)', '퓨어 클렌저', '원더드로잉 아이브로우 키트', '딥 클렌징오일', '페이스 파우더 브러쉬', '슈슈 선크림 민트 [SPF48/PA+++]', '아쿠아 수분 크림', '아이래쉬 컬러(뷰러)', '포멜로 파라디', '퓨리파잉 클렌징 오일', '올리브 리얼 스킨', '밸런싱 클렌저', '리지스트 슈퍼-라이트 선스크린 [SPF30]', '이드라 베베 페이셜 크림', '허니 모이스트 크림', '프리미엄 피치 뽀송 토너', '유기농 순면커버 생리대 대형', '타투 아이브로우', '스팟 컨실러', '클리어 로션', '화이트닝 마스크 팩', '자윤비책 지성 샴푸', '모이스처 리페어 샴푸', '퍼펙트 리뉴 에멀젼', '크림', '안티 덴드러프 샴푸', '세라마이딘 크림', '맨올로지 101 에센셜 모이스춰라이저', '프리미엄 폼클렌징', '프리미엄 피치 뽀송 에멀전', '퓨리파잉 클렌저', '베이비 모이스처라이저', '노니비누', '리프팅 마스크', '4D 마스카라', '웨지 스폰지', '두피 딥클렌징 샴푸', '올리브 & 그린티 바디 버터', '플라워 셀 크림', '드라이 스킨 크림', '아이슬란드 수분 에센스', '세라마이드 수분크림', '샴푸앤바스', '실크 브라운', 'EGF 리페어 앰플', '가부키 브러시', '립 페인트', '뷰티 너리싱 바디워시', '퓨어 컬러 블러셔', '올인원 로션', '버터볼', '골드 캐비어 크림', '퓨어 브라이트닝 에센스', '모이스춰 앤 너리싱 페이스 크림', '에코 소울 에센스 쿠션 모이스처 래스팅 [SPF50+/PA++++]', '네일 라커 ', '아이 컬러 브러쉬', '워터프루프 펜슬 젤라이너', '에스에너지 올데이 모이스트 에멀젼', '마유 클래식 100', '모이스춰 에센스', '닥터지움 올 클리어 앰플', '울트라 훼이셜 크림', '어성초 발효 세럼', '루트리션 크림', '스킨토너', '파우더 아이브로우', '브러쉬 세트', '퍼퓸드 핸드크림 - 체리블라썸', '딥 클린 클렌징 오일', '마유 마스크팩', '프레스트 파우더', '파우더 파운데이션 브러쉬', '에이지 컨트롤 스킨 소프너', '커피 바디 스크럽 클렌저 라벤더', '코튼 블러셔', '맨올로지 101 프리 토너', '리제너레이팅 크림', 'HD 블러쉬', '피부톤을 올려주는 하얀꽃 크림', '자정미백크림', '에센스 미스트', '갈락토미 클리어스킨 토너', '폴리젠 스칼프 바이탈 앰플', '화이트 머스크 퍼퓸 바디워시', 'AC 컨트롤 로션', '수분가득 콜라겐 미스트', '모이스트 업 히아루론 앰플 토너', '루즈 언리미티드 슈프림 마뜨', '모이스춰 로션', '바디밀크', '라이트 로션', '울트라블랜드', '유자 클렌징크림', '멀티 글리터', '퍼퓸네일', '플로리아 화이트닝 크림', '손 소독제', '헬씨 믹스 컨실러', '세보샴푸', '오프레시 딥 허벌 샴푸', '벨벳 데미지 리페어 트리트먼트', '모이스춰라이징 립 밤', '글로우 미스트', '티트리 카밍 젤 크림', '화이트 선 스크린 [SPF35]', '꿀광 로얄 프로폴리스 앰플 세럼 블랙', '난코 매스틱 퓨리파잉 토너', '내추럴 홍삼 마스크 시트', '슈가볼 벨벳 블러셔', '립 리페어', '콜라겐 드림 70 아이크림', '틴트 워터', '올웨이즈 뉴 오토 라이너', '인텐시브 리페어 샴푸', '올인원 톤업', '잇 스타일 헤어 스프레이', '마일드 버블 클렌저', '더마뉴얼 선블록 [SPF50+/PA+++]', '에어 인 퍼프 [블루]', '유주 앤 코코아 버블룬', '메이크업 리무버', '탑 젤', '좀비팩 & 페이스리프팅 엑티베이터 키트', '더마뉴얼 크림', '헤어 매치 브로우 카라', '모이스처 리치 샴푸', '레드 이레이징 크림', '매직 플래시 크림 [SPF25/PA++]', '바바수 액티브 퍼밍 에멀전', '젤리바', '글로시 립스틱', '더마톨로지 세럼', '프레셔스 라이트 리쥬버네이팅 일루미네이터', '우먼 오드뚜왈렛', '슬림 젤 아이라이너', '진 에센스', '크렘프레쉬 세럼', '포레스트 포맨 오일 컨트롤 올인원 에센스', '아쿠아 필 토너', '크림 아이섀도우', '비비드 틴트 루즈', '에코 어스 파워 라이트 선 크림 [SPF50+/PA+++]', '알페 디 36 앰플', '캡처 히아루로닉 앰플', '마이 갈바닉', '앵글드 아이라이너 브러쉬', '립 라커', '뷰티 메탈 쿠션 파운데이션 [SPF50+/PA+++]', '올리브 리얼 모이스처 핸드크림', '화장솜', '플랫 파운데이션 브러쉬', '실키 화장솜', '망고화이트 바디 워시', '로즈', '모링가 바디 스크럽', '내추럴 컨디션 클렌징 로션', '클리어 스팟 패치', '오가니언스 세럼', '777 아이섀도우', '에이피이 프로아틴 마스크', '포맨 스킨', '티트리 토너', '블랜딩 브러쉬', '글로우 립스틱', '핸드 앤 네일 트리트먼트 크림', '제모 크림', '아크네 컨트롤 클렌징폼', '실크 헤어 리페어 컬 세럼', '내추럴 블루베리 마스크 시트', '유채꿀 핸드 버터', '펜슬 컨실러', '야생녹차 이슬 에센스', '수정화장 패드', '발샴푸', '워터글로우 인젝션 마스크', '순백 크림', '수분가득 콜라겐 에센스', '코튼 퍼프', '모이스춰라이징 크림', '어성초 크림', '젤 클렌저', '글로우 틴트 스틱', '순면화장솜', '팬티라이너 롱', '화이트닝 선블럭', '모링가 리페어링 샴푸', '쉐이빙 크림', '프로페셔널 파운데이션 브러쉬', '케이스 케론 퍼프', '글로리 P10', '비즈 퓨어 스킨', '립스틱 매트', '딥클렌징 샴푸', '진설크림', '블랙베리', '어반 쉐이드 안티폴루션 선 [SPF50+/PA++++]', '하드와이어드 아이섀도우', '프렌치부케 트리트먼트', '모닝 밀크 버블 폼', '풀커버 크림 컨실러', '부스터 세럼', '울트라 화이트닝 크림', '마린 스파 바이탈 마스크 컨트롤 수딩', '패션 오 드 퍼퓸', '아이브로우 틴트', '그린티 카밍 클렌징 젤', '모공제로 나이트크림', ...

# %%
products_refined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87419 entries, 0 to 89058
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      87419 non-null  object
#  1   rank            87419 non-null  int64
#  2   title           87419 non-null  object
#  3   volume          87419 non-null  object
#  4   price           87396 non-null  float64
#  5   reviewCnt       87419 non-null  int64
#  6   ratingAvg       87419 non-null  float64
#  7   productImg      87418 non-null  object
#  8   isDiscontinue   87419 non-null  object
#  9   rankChange      87419 non-null  object
#  10  rankChangeType  87419 non-null  object
#  11  brand           87419 non-null  object
#  12  goodsInfo       87419 non-null  object
#  13  brandName       87419 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 10.0+ MB

# %%
df_products = products_refined.copy ()

# %%
'코스메티 LED 마스크' in duplication_title_list
# Out:
# False

# %%
def transform_ (df, duplication_title_list):
    df ['title'] = df.apply (lambda row : row ['title'] + '_' + str (row ['product_id']) 
                             if row ['title'] in duplication_title_list 
                             else row ['title'], axis = 1)

# %%
transform_ (df_products, duplication_title_list)

# %%
df_products [df_products ['title'].isin (duplication_title_list)]
# Out:
# Empty DataFrame
# Columns: [product_id, rank, title, volume, price, reviewCnt, ratingAvg, productImg, isDiscontinue, rankChange, rankChangeType, brand, goodsInfo, brandName]
# Index: []

# %%
products_refined [products_refined ['title'] == '벨벳 립스틱']
# Out:
#       product_id  rank   title volume    price  reviewCnt  ratingAvg  \
# 33778      85917    37  벨벳 립스틱   3.5g  15000.0         47       4.36
# 33923      99449   182  벨벳 립스틱     2g  10000.0          3       2.00
#
#                                               productImg isDiscontinue  \
# 33778  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 33923  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#       rankChange rankChangeType  \
# 33778          0           show
# 33923          0           show
#
#                                                    brand          goodsInfo  \
# 33778  {'idBrand': None, 'brandTitle': '모아트 (MOART)',...  {'goodsCount': 0}
# 33923  {'idBrand': None, 'brandTitle': 'VT COSMETICS ...  {'goodsCount': 0}
#
#                     brandName
# 33778             모아트 (MOART)
# 33923  VT COSMETICS (브이티코스메틱)

# %%
df_products [df_products ['title'] == '벨벳 립스틱_85917']
# Out:
#       product_id  rank         title volume    price  reviewCnt  ratingAvg  \
# 33778      85917    37  벨벳 립스틱_85917   3.5g  15000.0         47       4.36
#
#                                               productImg isDiscontinue  \
# 33778  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#       rankChange rankChangeType  \
# 33778          0           show
#
#                                                    brand          goodsInfo  \
# 33778  {'idBrand': None, 'brandTitle': '모아트 (MOART)',...  {'goodsCount': 0}
#
#          brandName
# 33778  모아트 (MOART)

# %%
df_products [df_products ['title'] == '벨벳 립스틱_99449']
# Out:
#       product_id  rank         title volume    price  reviewCnt  ratingAvg  \
# 33923      99449   182  벨벳 립스틱_99449     2g  10000.0          3        2.0
#
#                                               productImg isDiscontinue  \
# 33923  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#       rankChange rankChangeType  \
# 33923          0           show
#
#                                                    brand          goodsInfo  \
# 33923  {'idBrand': None, 'brandTitle': 'VT COSMETICS ...  {'goodsCount': 0}
#
#                     brandName
# 33923  VT COSMETICS (브이티코스메틱)

# %%
products_refined [products_refined ['title'] == '립스틱']
# Out:
#       product_id  rank title volume    price  reviewCnt  ratingAvg  \
# 15138       3108    17   립스틱     3g  31000.0      10508       4.17
# 15486         12     0   립스틱   3.4g  37000.0        713       4.08
#
#                                               productImg isDiscontinue  \
# 15138  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 15486  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...          True
#
#       rankChange rankChangeType  \
# 15138          2           show
# 15486          0           hide
#
#                                                    brand          goodsInfo  \
# 15138  {'idBrand': None, 'brandTitle': '맥 (MAC)', 'br...  {'goodsCount': 0}
# 15486  {'idBrand': None, 'brandTitle': '나스 (NARS)', '...  {'goodsCount': 0}
#
#        brandName
# 15138    맥 (MAC)
# 15486  나스 (NARS)

# %%
df_products [df_products ['title'] == '립스틱_3108']
# Out:
#       product_id  rank     title volume    price  reviewCnt  ratingAvg  \
# 15138       3108    17  립스틱_3108     3g  31000.0      10508       4.17
#
#                                               productImg isDiscontinue  \
# 15138  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#       rankChange rankChangeType  \
# 15138          2           show
#
#                                                    brand          goodsInfo  \
# 15138  {'idBrand': None, 'brandTitle': '맥 (MAC)', 'br...  {'goodsCount': 0}
#
#       brandName
# 15138   맥 (MAC)

# %%
df_products [df_products ['title'] == '립스틱_12']
# Out:
#       product_id  rank   title volume    price  reviewCnt  ratingAvg  \
# 15486         12     0  립스틱_12   3.4g  37000.0        713       4.08
#
#                                               productImg isDiscontinue  \
# 15486  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...          True
#
#       rankChange rankChangeType  \
# 15486          0           hide
#
#                                                    brand          goodsInfo  \
# 15486  {'idBrand': None, 'brandTitle': '나스 (NARS)', '...  {'goodsCount': 0}
#
#        brandName
# 15486  나스 (NARS)

# %%
df_products ['title'].str.count (pat = '\_').sum ()
# Out:
# 2894

# %%
products_refined ['title'].str.count (pat = '\_').sum ()
# Out:
# 173

# %%
2894 - 173
# Out:
# 2721

# %%
reviews.isnull ().sum ()
# Out:
# contents         0
# created_at       0
# is_evaluation    0
# like_count       0
# rating           0
# review_id        0
# state            0
# user_id          0
# product_id       0
# dtype: int64

# %%
df_products.isnull ().sum ()
# Out:
# product_id         0
# rank               0
# title              0
# volume             0
# price             23
# reviewCnt          0
# ratingAvg          0
# productImg         1
# isDiscontinue      0
# rankChange         0
# rankChangeType     0
# brand              0
# goodsInfo          0
# brandName          0
# dtype: int64

# %%
users.isnull ().sum ()
# Out:
# age                   1
# birth_year            1
# email                 0
# gender                0
# is_blinded            0
# is_closed             0
# is_inactivated        0
# nickname              1
# profile_image     31597
# rank                  0
# review_count          0
# skin_type             0
# user_id               0
# dtype: int64

# %%
users.head ()
# Out:
#     age  birth_year                     email gender  is_blinded  is_closed  \
# 0  31.0      1990.0          yhcu88@naver.com      f           0      False
# 1  33.0      1988.0    winwinanna@hanmail.net      f           0      False
# 2  37.0      1984.0  dmswjddlskfk@hanmail.net      f           0      False
# 3  32.0      1989.0         deer402@naver.com      f           0      False
# 4  26.0      1995.0         kkr3348@naver.com      f           0      False
#
#    is_inactivated     nickname  \
# 0           False          희뷰리
# 1           False       소극적인뷰터
# 2           False  greengables
# 3            True          백비송
# 4           False         초코감귤
#
#                                        profile_image   rank  review_count  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  27347            44
# 1                                                NaN  41582            15
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...    946           375
# 3  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  43404            29
# 4  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...   9386            97
#
#   skin_type  user_id
# 0       복합성  1281918
# 1        건성  1255686
# 2        지성   631689
# 3        건성  1188087
# 4       복합성   632220

# %%
len (users ['age'].unique ())
# Out:
# 79

# %%
users ['age'].value_counts ().head (47)
# Out:
# 25.0    6368
# 26.0    6005
# 24.0    5688
# 27.0    5017
# 23.0    4918
# 21.0    4568
# 28.0    4118
# 22.0    4084
# 20.0    3942
# 29.0    3769
# 19.0    3675
# 18.0    3582
# 30.0    2982
# 17.0    2922
# 31.0    2549
# 32.0    1854
# 16.0    1637
# 33.0    1526
# 34.0    1209
# 35.0     949
# 36.0     781
# 15.0     722
# 37.0     604
# 38.0     537
# 39.0     443
# 40.0     351
# 41.0     288
# 42.0     194
# 14.0     151
# 44.0     124
# 43.0      98
# 45.0      86
# 46.0      83
# 48.0      71
# 47.0      61
# 49.0      57
# 50.0      55
# 51.0      53
# 4.0       51
# 52.0      33
# 6.0       32
# 54.0      28
# 53.0      25
# 13.0      22
# 56.0      20
# 55.0      18
# 57.0      14
# Name: age, dtype: int64

# %%
users ['age'].value_counts ().tail (32)
# Out:
#  57.0      14
#  121.0     11
#  58.0      11
#  7.0       11
#  12.0      10
#  3.0        9
#  2.0        9
#  60.0       8
#  104.0      6
#  62.0       5
#  61.0       5
#  11.0       5
#  101.0      5
#  59.0       4
#  72.0       2
#  103.0      2
#  71.0       2
#  102.0      2
#  64.0       2
#  8.0        2
#  63.0       2
#  105.0      2
# -518.0      1
#  67.0       1
#  70.0       1
#  9.0        1
#  89.0       1
#  98.0       1
#  2016.0     1
#  68.0       1
#  2018.0     1
#  1995.0     1
# Name: age, dtype: int64

# %%
users.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76490 entries, 0 to 76489
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             76489 non-null  float64
#  1   birth_year      76489 non-null  float64
#  2   email           76490 non-null  object
#  3   gender          76490 non-null  object
#  4   is_blinded      76490 non-null  int64
#  5   is_closed       76490 non-null  bool
#  6   is_inactivated  76490 non-null  bool
#  7   nickname        76489 non-null  object
#  8   profile_image   44893 non-null  object
#  9   rank            76490 non-null  int64
#  10  review_count    76490 non-null  int64
#  11  skin_type       76490 non-null  object
#  12  user_id         76490 non-null  object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 6.6+ MB

# %%
# 0세 ~ 90세 회원 정보만 뽑아냄.  음수나이와 90세 이상은 제외
users = users [(users ['age'] < 90) & (users ['age'] > 0)]
users.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76456 entries, 0 to 76489
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             76456 non-null  float64
#  1   birth_year      76456 non-null  float64
#  2   email           76456 non-null  object
#  3   gender          76456 non-null  object
#  4   is_blinded      76456 non-null  int64
#  5   is_closed       76456 non-null  bool
#  6   is_inactivated  76456 non-null  bool
#  7   nickname        76455 non-null  object
#  8   profile_image   44871 non-null  object
#  9   rank            76456 non-null  int64
#  10  review_count    76456 non-null  int64
#  11  skin_type       76456 non-null  object
#  12  user_id         76456 non-null  object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 7.1+ MB

# %%
users.describe ()
# Out:
#                 age    birth_year  is_blinded          rank  review_count
# count  76456.000000  76456.000000     76456.0  7.645600e+04  76456.000000
# mean      25.250118   1995.749882         0.0  6.909060e+04     41.476823
# std        5.984109      5.984109         0.0  5.044060e+05     56.878904
# min        2.000000   1932.000000         0.0  1.000000e+00    -46.000000
# 25%       21.000000   1993.000000         0.0  1.853600e+04     10.000000
# 50%       25.000000   1996.000000         0.0  3.840400e+04     26.000000
# 75%       28.000000   2000.000000         0.0  6.279600e+04     51.000000
# max       89.000000   2019.000000         0.0  9.999999e+06   2003.000000

# %%
users.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76490 entries, 0 to 76489
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             76490 non-null  float64
#  1   birth_year      76490 non-null  float64
#  2   email           76490 non-null  object
#  3   gender          76490 non-null  object
#  4   is_blinded      76490 non-null  int64
#  5   is_closed       76490 non-null  bool
#  6   is_inactivated  76490 non-null  bool
#  7   nickname        76489 non-null  object
#  8   profile_image   44893 non-null  object
#  9   rank            76490 non-null  int64
#  10  review_count    76490 non-null  int64
#  11  skin_type       76490 non-null  object
#  12  user_id         76490 non-null  object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 6.6+ MB

# %%
reviews.describe ()
# Out:
#          like_count        rating
# count  1.574817e+06  1.574817e+06
# mean   4.032602e-01  3.775028e+00
# std    2.401369e+00  1.097055e+00
# min    0.000000e+00  1.000000e+00
# 25%    0.000000e+00  3.000000e+00
# 50%    0.000000e+00  4.000000e+00
# 75%    0.000000e+00  5.000000e+00
# max    4.940000e+02  5.000000e+00

# %%
df_products.describe ()
# Out:
#                rank         price     reviewCnt     ratingAvg
# count  87419.000000  8.739600e+04  87419.000000  87419.000000
# mean     135.845960  3.177278e+04     36.477368      2.559236
# std      232.053576  5.114588e+04    243.091671      1.881431
# min        0.000000  0.000000e+00      0.000000      0.000000
# 25%        0.000000  9.800000e+03      0.000000      0.000000
# 50%       16.000000  2.000000e+04      2.000000      3.400000
# 75%      178.000000  3.600000e+04     10.000000      4.000000
# max     1397.000000  2.130000e+06  17521.000000      5.000000

# %%
df_products.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87419 entries, 0 to 89058
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      87419 non-null  object
#  1   rank            87419 non-null  int64
#  2   title           87419 non-null  object
#  3   volume          87419 non-null  object
#  4   price           87396 non-null  float64
#  5   reviewCnt       87419 non-null  int64
#  6   ratingAvg       87419 non-null  float64
#  7   productImg      87418 non-null  object
#  8   isDiscontinue   87419 non-null  object
#  9   rankChange      87419 non-null  object
#  10  rankChangeType  87419 non-null  object
#  11  brand           87419 non-null  object
#  12  goodsInfo       87419 non-null  object
#  13  brandName       87419 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 10.0+ MB

# %%
df_products.head ()
# Out:
#   product_id  rank                 title volume      price  reviewCnt  \
# 0     108711     5          코스메티 LED 마스크    1ea   219000.0          4
# 1     118971     6               LED 마스크    1ea   149000.0          2
# 2     118819     7  디쎄 1.0 LED 마스크 [업무용]    1ea  1320000.0          1
# 3      90929     8            LED 리얼 마스크    1ea   198000.0          1
# 4     127206     9     인텐시브 LED 마스크 프리미엄    1ea  1517100.0          1
#
#    ratingAvg                                         productImg isDiscontinue  \
# 0       3.75  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 2       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 3       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 4       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#   rankChange rankChangeType  \
# 0          0           show
# 1          0           show
# 2          0           show
# 3          0           show
# 4          0           show
#
#                                                brand          goodsInfo  \
# 0  {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...  {'goodsCount': 0}
# 1  {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...  {'goodsCount': 0}
# 2  {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...  {'goodsCount': 0}
# 3  {'idBrand': None, 'brandTitle': '솔루미에스테 (SOLLU...  {'goodsCount': 0}
# 4  {'idBrand': None, 'brandTitle': '엘리닉 (L Linic)...  {'goodsCount': 0}
#
#                 brandName
# 0                 아름다운연구소
# 1           에끌레어 (eclair)
# 2     닥터슈라클 (Dr.Ceuracle)
# 3  솔루미에스테 (SOLLUME ESTHE)
# 4           엘리닉 (L Linic)

# %%
reviews.describe ()
# Out:
#          like_count        rating
# count  1.574817e+06  1.574817e+06
# mean   4.032602e-01  3.775028e+00
# std    2.401369e+00  1.097055e+00
# min    0.000000e+00  1.000000e+00
# 25%    0.000000e+00  3.000000e+00
# 50%    0.000000e+00  4.000000e+00
# 75%    0.000000e+00  5.000000e+00
# max    4.940000e+02  5.000000e+00

# %%
reviews.isnull ().sum ()
# Out:
# contents         0
# created_at       0
# is_evaluation    0
# like_count       0
# rating           0
# review_id        0
# state            0
# user_id          0
# product_id       0
# dtype: int64

# %%
reviews.dtypes
# Out:
# contents         object
# created_at       object
# is_evaluation      bool
# like_count        int64
# rating            int64
# review_id        object
# state            object
# user_id          object
# product_id       object
# dtype: object

# %%
users.dtypes
# Out:
# age               float64
# birth_year        float64
# email              object
# gender             object
# is_blinded          int64
# is_closed            bool
# is_inactivated       bool
# nickname           object
# profile_image      object
# rank                int64
# review_count        int64
# skin_type          object
# user_id            object
# dtype: object

# %%
users.isnull ().sum ()
# Out:
# age                   0
# birth_year            0
# email                 0
# gender                0
# is_blinded            0
# is_closed             0
# is_inactivated        0
# nickname              1
# profile_image     31585
# rank                  0
# review_count          0
# skin_type             0
# user_id               0
# dtype: int64

# %%
review_user_df = pd.merge (reviews, users, how = 'left', on = 'user_id')
review_user_df.head ()
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
# 3                           순하고 가격적으로 무난해서 쓰기 괜찮아요오오  2020-01-18T08:03:59Z
# 4  성분이 착해서 샀고 타입이 폼이라 짜서 쓰는 젤보다 약간 귀찮지만 거품은 바로 많이...  2020-01-11T07:15:15Z
#
#    is_evaluation  like_count  rating review_id state  user_id product_id  \
# 0          False           0       3   5416271     N   119763     100000
# 1          False           0       4   5340616     N   338669     100000
# 2          False           0       3   5228598     N    24862     100000
# 3          False           0       4   5225359     N  1331797     100000
# 4          False           0       4   5211274     N   888968     100000
#
#     age  ...                   email gender is_blinded  is_closed  \
# 0  36.0  ...     intears23@naver.com      f        0.0      False
# 1  38.0  ...   hihearyeong@naver.com      f        0.0      False
# 2  28.0  ...     leemj1993@naver.com      f        0.0      False
# 3  20.0  ...    betcha2001@naver.com      f        0.0      False
# 4  33.0  ...  milk_madam@hanmail.net      f        0.0      False
#
#   is_inactivated nickname                                      profile_image  \
# 0          False      kyo  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 1          False       뭐라  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...
# 2          False       민졍                                                NaN
# 3          False  Gravity                                                NaN
# 4          False     이게모람  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
#
#       rank  review_count  skin_type
# 0   2914.0         205.0        복합성
# 1   1023.0         285.0         중성
# 2   2292.0         230.0        복합성
# 3  36233.0          36.0        복합성
# 4   6737.0         108.0        복합성
#
# [5 rows x 21 columns]

# %%
review_user_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1574817 entries, 0 to 1574816
# Data columns (total 21 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   contents        1574817 non-null  object
#  1   created_at      1574817 non-null  object
#  2   is_evaluation   1574817 non-null  bool
#  3   like_count      1574817 non-null  int64
#  4   rating          1574817 non-null  int64
#  5   review_id       1574817 non-null  object
#  6   state           1574817 non-null  object
#  7   user_id         1574817 non-null  object
#  8   product_id      1574817 non-null  object
#  9   age             1472552 non-null  float64
#  10  birth_year      1472552 non-null  float64
#  11  email           1472552 non-null  object
#  12  gender          1472552 non-null  object
#  13  is_blinded      1472552 non-null  float64
#  14  is_closed       1472552 non-null  object
#  15  is_inactivated  1472552 non-null  object
#  16  nickname        1472541 non-null  object
#  17  profile_image   1025867 non-null  object
#  18  rank            1472552 non-null  float64
#  19  review_count    1472552 non-null  float64
#  20  skin_type       1472552 non-null  object
# dtypes: bool(1), float64(5), int64(2), object(13)
# memory usage: 253.8+ MB

# %%
df_products.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87419 entries, 0 to 89058
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      87419 non-null  object
#  1   rank            87419 non-null  int64
#  2   title           87419 non-null  object
#  3   volume          87419 non-null  object
#  4   price           87396 non-null  float64
#  5   reviewCnt       87419 non-null  int64
#  6   ratingAvg       87419 non-null  float64
#  7   productImg      87418 non-null  object
#  8   isDiscontinue   87419 non-null  object
#  9   rankChange      87419 non-null  object
#  10  rankChangeType  87419 non-null  object
#  11  brand           87419 non-null  object
#  12  goodsInfo       87419 non-null  object
#  13  brandName       87419 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 10.0+ MB

# %%
review_user_product_df = pd.merge (review_user_df, df_products, how = 'left', on = 'product_id')
review_user_product_df.head (3)
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
#
#    is_evaluation  like_count  rating review_id state user_id product_id   age  \
# 0          False           0       3   5416271     N  119763     100000  36.0
# 1          False           0       4   5340616     N  338669     100000  38.0
# 2          False           0       3   5228598     N   24862     100000  28.0
#
#    ...    price reviewCnt ratingAvg  \
# 0  ...  11000.0      11.0      3.64
# 1  ...  11000.0      11.0      3.64
# 2  ...  11000.0      11.0      3.64
#
#                                           productImg isDiscontinue rankChange  \
# 0  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 1  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
# 2  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False          0
#
#   rankChangeType                                              brand  \
# 0           show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 1           show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 2           show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
#
#            goodsInfo          brandName
# 0  {'goodsCount': 0}  해피바스 (HAPPY BATH)
# 1  {'goodsCount': 0}  해피바스 (HAPPY BATH)
# 2  {'goodsCount': 0}  해피바스 (HAPPY BATH)
#
# [3 rows x 34 columns]

# %%
product_categories.head (3)
# Out:
#   product_id  rank                 title volume      price  reviewCnt  \
# 0     108711     5          코스메티 LED 마스크    1ea   219000.0          4
# 1     118971     6               LED 마스크    1ea   149000.0          2
# 2     118819     7  디쎄 1.0 LED 마스크 [업무용]    1ea  1320000.0          1
#
#    ratingAvg                                         productImg isDiscontinue  \
# 0       3.75  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 2       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#   rankChange rankChangeType  \
# 0          0           show
# 1          0           show
# 2          0           show
#
#                                                brand          goodsInfo  \
# 0  {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...  {'goodsCount': 0}
# 1  {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...  {'goodsCount': 0}
# 2  {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...  {'goodsCount': 0}
#
#              brandName firstCategoryText  idFirstCategory  idSecondCategory  \
# 0              아름다운연구소              디바이스             16.0              85.0
# 1        에끌레어 (eclair)              디바이스             16.0              85.0
# 2  닥터슈라클 (Dr.Ceuracle)              디바이스             16.0              85.0
#
#    idThirdCategory secondCategoryText thirdCategoryText
# 0            255.0             뷰티디바이스            LED마스크
# 1            255.0             뷰티디바이스            LED마스크
# 2            255.0             뷰티디바이스            LED마스크

# %%
product_categories.head (3)
# Out:
#   firstCategoryText  idFirstCategory  idSecondCategory  idThirdCategory  \
# 0             프래그런스               15                83              246
# 1               클렌징                7                32              112
# 2             립메이크업                3                15               50
#
#   secondCategoryText thirdCategoryText product_id
# 0                 향수              여성향수      10000
# 1             페이셜클렌저              클렌징폼     100000
# 2             립틴트/라커           글로시/젤틴트       1030

# %%
review_user_product_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1574817 entries, 0 to 1574816
# Data columns (total 34 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   contents        1574817 non-null  object
#  1   created_at      1574817 non-null  object
#  2   is_evaluation   1574817 non-null  bool
#  3   like_count      1574817 non-null  int64
#  4   rating          1574817 non-null  int64
#  5   review_id       1574817 non-null  object
#  6   state           1574817 non-null  object
#  7   user_id         1574817 non-null  object
#  8   product_id      1574817 non-null  object
#  9   age             1472144 non-null  float64
#  10  birth_year      1472144 non-null  float64
#  11  email           1472144 non-null  object
#  12  gender          1472144 non-null  object
#  13  is_blinded      1472144 non-null  float64
#  14  is_closed       1472144 non-null  object
#  15  is_inactivated  1472144 non-null  object
#  16  nickname        1472133 non-null  object
#  17  profile_image   1025674 non-null  object
#  18  rank_x          1472144 non-null  float64
#  19  review_count    1472144 non-null  float64
#  20  skin_type       1472144 non-null  object
#  21  rank_y          1564554 non-null  float64
#  22  title           1564554 non-null  object
#  23  volume          1564554 non-null  object
#  24  price           1564257 non-null  float64
#  25  reviewCnt       1564554 non-null  float64
#  26  ratingAvg       1564554 non-null  float64
#  27  productImg      1564552 non-null  object
#  28  isDiscontinue   1564554 non-null  object
#  29  rankChange      1564554 non-null  object
#  30  rankChangeType  1564554 non-null  object
#  31  brand           1564554 non-null  object
#  32  goodsInfo       1564554 non-null  object
#  33  brandName       1564554 non-null  object
# dtypes: bool(1), float64(9), int64(2), object(22)
# memory usage: 410.0+ MB

# %%
total_merged_df = pd.merge (review_user_product_df, product_categories, how = 'left', on = 'product_id')
total_merged_df.head (3)
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
#
#    is_evaluation  like_count  rating review_id state user_id product_id   age  \
# 0          False           0       3   5416271     N  119763     100000  36.0
# 1          False           0       4   5340616     N  338669     100000  38.0
# 2          False           0       3   5228598     N   24862     100000  28.0
#
#    ...  rankChangeType                                              brand  \
# 0  ...            show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 1  ...            show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 2  ...            show  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
#
#            goodsInfo          brandName firstCategoryText idFirstCategory  \
# 0  {'goodsCount': 0}  해피바스 (HAPPY BATH)               클렌징             7.0
# 1  {'goodsCount': 0}  해피바스 (HAPPY BATH)               클렌징             7.0
# 2  {'goodsCount': 0}  해피바스 (HAPPY BATH)               클렌징             7.0
#
#   idSecondCategory idThirdCategory  secondCategoryText  thirdCategoryText
# 0             32.0           112.0              페이셜클렌저               클렌징폼
# 1             32.0           112.0              페이셜클렌저               클렌징폼
# 2             32.0           112.0              페이셜클렌저               클렌징폼
#
# [3 rows x 40 columns]

# %%
len (total_merged_df)
# Out:
# 1965802

# %%
categor

# %%
product_categories.head (20)
# Out:
#    product_id  rank                          title volume      price  \
# 0      108711     5                   코스메티 LED 마스크    1ea   219000.0
# 1      118971     6                        LED 마스크    1ea   149000.0
# 2      118819     7           디쎄 1.0 LED 마스크 [업무용]    1ea  1320000.0
# 3       90929     8                     LED 리얼 마스크    1ea   198000.0
# 4      127206     9              인텐시브 LED 마스크 프리미엄    1ea  1517100.0
# 5      131956    10                 플러스 더마 LED 마스크    1ea   899000.0
# 6      127123    11                   인텐시브 LED 마스크    1ea   990000.0
# 7      119892    12             디쎄 홈 LED 마스크 [3파장]     1p   720000.0
# 8      125570     0  LED 라이트 테라피 페이스 마스크 version 2    1ea   139000.0
# 9      125568     0   LED 라이트 테라피 페이스 마스크 version1    1ea    65000.0
# 10     131989     0                    LED 테라피 마스크    1ea   149000.0
# 11     131952     0                  LED마스크 라이트플러스    1ea   899000.0
# 12     131952     0                  LED마스크 라이트플러스    1ea   899000.0
# 13     131953     0                 LED마스크 라이트플러스2    1ea  1120000.0
# 14     131954     0                   LED마스크 블랙에디션    1ea  1747000.0
# 15     131935     0                    LED마스크 프리미엄    1ea  1747000.0
# 16     127680     0                    LED마스크 플래티넘    1ea  2130000.0
# 17     104217     0                   근적외선 LED 마스크    1ea  1345000.0
# 18     118037     0                     더마 LED 마스크    1ea   368000.0
# 19     117821     0                  더마 LED 마스크 6     1ea  1790000.0
#
#     reviewCnt  ratingAvg                                         productImg  \
# 0           4       3.75  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 1           2       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 2           1       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 3           1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 4           1       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 5           1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/var/app/c...
# 6           1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 7           1       3.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 8           0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 9           0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 10          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/var/app/c...
# 11          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/var/app/c...
# 12          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/var/app/c...
# 13          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/var/app/c...
# 14          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/var/app/c...
# 15          1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/var/app/c...
# 16          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 17          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 18          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
# 19          0       0.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...
#
#    isDiscontinue rankChange rankChangeType  \
# 0          False          0           show
# 1          False          0           show
# 2          False          0           show
# 3          False          0           show
# 4          False          0           show
# 5          False          0            new
# 6          False         -1           show
# 7          False         -1           show
# 8          False          0           hide
# 9          False          0           hide
# 10         False          0           hide
# 11         False          0           hide
# 12         False          0           hide
# 13         False          0           hide
# 14         False          0           hide
# 15         False          0           hide
# 16         False          0           hide
# 17         False          0           hide
# 18         False          0           hide
# 19         False          0           hide
#
#                                                 brand          goodsInfo  \
# 0   {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...  {'goodsCount': 0}
# 1   {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...  {'goodsCount': 0}
# 2   {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...  {'goodsCount': 0}
# 3   {'idBrand': None, 'brandTitle': '솔루미에스테 (SOLLU...  {'goodsCount': 0}
# 4   {'idBrand': None, 'brandTitle': '엘리닉 (L Linic)...  {'goodsCount': 0}
# 5   {'idBrand': None, 'brandTitle': '프라엘 (Pra L)',...  {'goodsCount': 0}
# 6   {'idBrand': None, 'brandTitle': '엘리닉 (L Linic)...  {'goodsCount': 0}
# 7   {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...  {'goodsCount': 0}
# 8   {'idBrand': None, 'brandTitle': '웰더마 (WellDerm...  {'goodsCount': 0}
# 9   {'idBrand': None, 'brandTitle': '웰더마 (WellDerm...  {'goodsCount': 0}
# 10  {'idBrand': None, 'brandTitle': '셀라랩 (CELLA LA...  {'goodsCount': 0}
# 11  {'idBrand': None, 'brandTitle': '셀리턴 (CELLRETU...  {'goodsCount': 0}
# 12  {'idBrand': None, 'brandTitle': '셀리턴 (CELLRETU...  {'goodsCount': 0}
# 13  {'idBrand': None, 'brandTitle': '셀리턴 (CELLRETU...  {'goodsCount': 0}
# 14  {'idBrand': None, 'brandTitle': '셀리턴 (CELLRETU...  {'goodsCount': 0}
# 15  {'idBrand': None, 'brandTitle': '셀리턴 (CELLRETU...  {'goodsCount': 0}
# 16  {'idBrand': None, 'brandTitle': '셀리턴 (CELLRETU...  {'goodsCount': 0}
# 17  {'idBrand': None, 'brandTitle': '엠엠코리아 (mmkore...  {'goodsCount': 0}
# 18  {'idBrand': None, 'brandTitle': '티에스트 (TIEST)'...  {'goodsCount': 0}
# 19  {'idBrand': None, 'brandTitle': '더레드립 (THE RED...  {'goodsCount': 0}
#
#                  brandName firstCategoryText  idFirstCategory  \
# 0                  아름다운연구소              디바이스             16.0
# 1            에끌레어 (eclair)              디바이스             16.0
# 2      닥터슈라클 (Dr.Ceuracle)              디바이스             16.0
# 3   솔루미에스테 (SOLLUME ESTHE)              디바이스             16.0
# 4            엘리닉 (L Linic)              디바이스             16.0
# 5              프라엘 (Pra L)              디바이스             16.0
# 6            엘리닉 (L Linic)              디바이스             16.0
# 7      닥터슈라클 (Dr.Ceuracle)              디바이스             16.0
# 8          웰더마 (WellDerma)              디바이스             16.0
# 9          웰더마 (WellDerma)              디바이스             16.0
# 10         셀라랩 (CELLA LAB)              디바이스             16.0
# 11        셀리턴 (CELLRETURN)              스킨케어              1.0
# 12        셀리턴 (CELLRETURN)              디바이스             16.0
# 13        셀리턴 (CELLRETURN)              디바이스             16.0
# 14        셀리턴 (CELLRETURN)              디바이스             16.0
# 15        셀리턴 (CELLRETURN)              디바이스             16.0
# 16        셀리턴 (CELLRETURN)              디바이스             16.0
# 17         엠엠코리아 (mmkorea)              디바이스             16.0
# 18            티에스트 (TIEST)              디바이스             16.0
# 19      더레드립 (THE RED LIP)              디바이스             16.0
#
#     idSecondCategory  idThirdCategory secondCategoryText thirdCategoryText
# 0               85.0            255.0             뷰티디바이스            LED마스크
# 1               85.0            255.0             뷰티디바이스            LED마스크
# 2               85.0            255.0             뷰티디바이스            LED마스크
# 3               85.0            255.0             뷰티디바이스            LED마스크
# 4               85.0            255.0             뷰티디바이스            LED마스크
# 5               85.0            255.0             뷰티디바이스            LED마스크
# 6               85.0            255.0             뷰티디바이스            LED마스크
# 7               85.0            255.0             뷰티디바이스            LED마스크
# 8               85.0            255.0             뷰티디바이스            LED마스크
# 9               85.0            255.0             뷰티디바이스            LED마스크
# 10              85.0            255.0             뷰티디바이스            LED마스크
# 11               3.0             16.0             에센스/세럼          브라이트닝에센스
# 12              85.0            255.0             뷰티디바이스            LED마스크
# 13              85.0            255.0             뷰티디바이스            LED마스크
# 14              85.0            255.0             뷰티디바이스            LED마스크
# 15              85.0            255.0             뷰티디바이스            LED마스크
# 16              85.0            255.0             뷰티디바이스            LED마스크
# 17              85.0            255.0             뷰티디바이스            LED마스크
# 18              85.0            255.0             뷰티디바이스            LED마스크
# 19              85.0            255.0             뷰티디바이스            LED마스크

# %%
df_1 = pd.DataFrame ({'A' : ['a', 'b', 'c'], 'B' : ['AAA', 'BBB', 'CCC']})
df_1
# Out:
#    A    B
# 0  a  AAA
# 1  b  BBB
# 2  c  CCC

# %%
df_3 = pd.DataFrame ({'A' : ['a', 'a', 'b', 'a'], 'value' : [1, 2, 3, 4]})
df_3
# Out:
#    A  value
# 0  a      1
# 1  a      2
# 2  b      3
# 3  a      4

# %%
df_1.merge(df_3, how='left', left_on='A', right_on='key')
# Out:
#    A    B  key  value
# 0  a  AAA    a    1.0
# 1  a  AAA    a    2.0
# 2  a  AAA    a    4.0
# 3  b  BBB    b    3.0
# 4  c  CCC  NaN    NaN

# %%
pd.merge (df_1, df_3, how = 'left', on = 'A')
# Out:
#    A    B  value
# 0  a  AAA    1.0
# 1  a  AAA    2.0
# 2  a  AAA    4.0
# 3  b  BBB    3.0
# 4  c  CCC    NaN

# %%
df_products.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87419 entries, 0 to 89058
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      87419 non-null  object
#  1   rank            87419 non-null  int64
#  2   title           87419 non-null  object
#  3   volume          87419 non-null  object
#  4   price           87396 non-null  float64
#  5   reviewCnt       87419 non-null  int64
#  6   ratingAvg       87419 non-null  float64
#  7   productImg      87418 non-null  object
#  8   isDiscontinue   87419 non-null  object
#  9   rankChange      87419 non-null  object
#  10  rankChangeType  87419 non-null  object
#  11  brand           87419 non-null  object
#  12  goodsInfo       87419 non-null  object
#  13  brandName       87419 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 10.0+ MB

# %%
product_categories.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96678 entries, 0 to 96677
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          96678 non-null  object
#  1   rank                96678 non-null  int64
#  2   title               96678 non-null  object
#  3   volume              96678 non-null  object
#  4   price               96650 non-null  float64
#  5   reviewCnt           96678 non-null  int64
#  6   ratingAvg           96678 non-null  float64
#  7   productImg          96677 non-null  object
#  8   isDiscontinue       96678 non-null  object
#  9   rankChange          96678 non-null  object
#  10  rankChangeType      96678 non-null  object
#  11  brand               96678 non-null  object
#  12  goodsInfo           96678 non-null  object
#  13  brandName           96678 non-null  object
#  14  firstCategoryText   86968 non-null  object
#  15  idFirstCategory     86968 non-null  float64
#  16  idSecondCategory    86968 non-null  float64
#  17  idThirdCategory     86968 non-null  float64
#  18  secondCategoryText  86968 non-null  object
#  19  thirdCategoryText   86955 non-null  object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 15.5+ MB

# %%
product_categories = pd.merge (df_products, product_categories, how = 'left', on = 'product_id')
product_categories.head (3)
# Out:
#   product_id  rank                 title volume      price  reviewCnt  \
# 0     108711     5          코스메티 LED 마스크    1ea   219000.0          4
# 1     118971     6               LED 마스크    1ea   149000.0          2
# 2     118819     7  디쎄 1.0 LED 마스크 [업무용]    1ea  1320000.0          1
#
#    ratingAvg                                         productImg isDiscontinue  \
# 0       3.75  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 1       4.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
# 2       5.00  https://d9vmi5fxk1gsw.cloudfront.net/home/glow...         False
#
#   rankChange rankChangeType  \
# 0          0           show
# 1          0           show
# 2          0           show
#
#                                                brand          goodsInfo  \
# 0  {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...  {'goodsCount': 0}
# 1  {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...  {'goodsCount': 0}
# 2  {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...  {'goodsCount': 0}
#
#              brandName firstCategoryText  idFirstCategory  idSecondCategory  \
# 0              아름다운연구소              디바이스             16.0              85.0
# 1        에끌레어 (eclair)              디바이스             16.0              85.0
# 2  닥터슈라클 (Dr.Ceuracle)              디바이스             16.0              85.0
#
#    idThirdCategory secondCategoryText thirdCategoryText
# 0            255.0             뷰티디바이스            LED마스크
# 1            255.0             뷰티디바이스            LED마스크
# 2            255.0             뷰티디바이스            LED마스크

# %%
product_categories.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96678 entries, 0 to 96677
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          96678 non-null  object
#  1   rank                96678 non-null  int64
#  2   title               96678 non-null  object
#  3   volume              96678 non-null  object
#  4   price               96650 non-null  float64
#  5   reviewCnt           96678 non-null  int64
#  6   ratingAvg           96678 non-null  float64
#  7   productImg          96677 non-null  object
#  8   isDiscontinue       96678 non-null  object
#  9   rankChange          96678 non-null  object
#  10  rankChangeType      96678 non-null  object
#  11  brand               96678 non-null  object
#  12  goodsInfo           96678 non-null  object
#  13  brandName           96678 non-null  object
#  14  firstCategoryText   86968 non-null  object
#  15  idFirstCategory     86968 non-null  float64
#  16  idSecondCategory    86968 non-null  float64
#  17  idThirdCategory     86968 non-null  float64
#  18  secondCategoryText  86968 non-null  object
#  19  thirdCategoryText   86955 non-null  object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 15.5+ MB

# %%
product_categories.isnull ().sum ()
# Out:
# product_id               0
# rank                     0
# title                    0
# volume                   0
# price                   28
# reviewCnt                0
# ratingAvg                0
# productImg               1
# isDiscontinue            0
# rankChange               0
# rankChangeType           0
# brand                    0
# goodsInfo                0
# brandName                0
# firstCategoryText     9710
# idFirstCategory       9710
# idSecondCategory      9710
# idThirdCategory       9710
# secondCategoryText    9710
# thirdCategoryText     9723
# dtype: int64

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87419 entries, 0 to 89058
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      87419 non-null  object
#  1   rank            87419 non-null  int64
#  2   title           87419 non-null  object
#  3   volume          87419 non-null  object
#  4   price           87396 non-null  float64
#  5   reviewCnt       87419 non-null  int64
#  6   ratingAvg       87419 non-null  float64
#  7   productImg      87418 non-null  object
#  8   isDiscontinue   87419 non-null  object
#  9   rankChange      87419 non-null  object
#  10  rankChangeType  87419 non-null  object
#  11  brand           87419 non-null  object
#  12  goodsInfo       87419 non-null  object
#  13  brandName       87419 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 10.0+ MB

# %%
total_merged_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1965802 entries, 0 to 1965801
# Data columns (total 40 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   contents            object
#  1   created_at          object
#  2   is_evaluation       bool
#  3   like_count          int64
#  4   rating              int64
#  5   review_id           object
#  6   state               object
#  7   user_id             object
#  8   product_id          object
#  9   age                 float64
#  10  birth_year          float64
#  11  email               object
#  12  gender              object
#  13  is_blinded          float64
#  14  is_closed           object
#  15  is_inactivated      object
#  16  nickname            object
#  17  profile_image       object
#  18  rank_x              float64
#  19  review_count        float64
#  20  skin_type           object
#  21  rank_y              float64
#  22  title               object
#  23  volume              object
#  24  price               float64
#  25  reviewCnt           float64
#  26  ratingAvg           float64
#  27  productImg          object
#  28  isDiscontinue       object
#  29  rankChange          object
#  30  rankChangeType      object
#  31  brand               object
#  32  goodsInfo           object
#  33  brandName           object
#  34  firstCategoryText   object
#  35  idFirstCategory     float64
#  36  idSecondCategory    float64
#  37  idThirdCategory     float64
#  38  secondCategoryText  object
#  39  thirdCategoryText   object
# dtypes: bool(1), float64(12), int64(2), object(25)
# memory usage: 601.8+ MB

# %%
total_merged_df.isnull ().sum ()
# Out:
# contents                   0
# created_at                 0
# is_evaluation              0
# like_count                 0
# rating                     0
# review_id                  0
# state                      0
# user_id                    0
# product_id                 0
# age                   128747
# birth_year            128747
# email                 128747
# gender                128747
# is_blinded            128747
# is_closed             128747
# is_inactivated        128747
# nickname              128760
# profile_image         686434
# rank_x                128747
# review_count          128747
# skin_type             128747
# rank_y                 12844
# title                  12844
# volume                 12844
# price                  13683
# reviewCnt              12844
# ratingAvg              12844
# productImg             12846
# isDiscontinue          12844
# rankChange             12844
# rankChangeType         12844
# brand                  12844
# goodsInfo              12844
# brandName              12844
# firstCategoryText      54684
# idFirstCategory        54684
# idSecondCategory       54684
# idThirdCategory        54684
# secondCategoryText     54684
# thirdCategoryText      55189
# dtype: int64

# %%
total_merged_df.astype ({'idFirstCategory' : 'int64', 'idSecondCategory' : 'int64', 'idThirdCategory' : 'int64'})
total_merged_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-2691514460b9> in <module>
# ----> 1 total_merged_df.astype ({'idFirstCategory' : 'int64', 'idSecondCategory' : 'int64', 'idThirdCategory' : 'int64'})
#       2 total_merged_df.dtypes
#
# ~/anaconda3/envs/torch2/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5681                 if col_name in dtype:
#    5682                     results.append(
# -> 5683                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5684                     )
#    5685                 else:
#
# ~/anaconda3/envs/torch2/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/envs/torch2/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/anaconda3/envs/torch2/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/envs/torch2/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/envs/torch2/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     866
#     867         if not np.isfinite(arr).all():
# --> 868             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     869
#     870     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
product_categories.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88756 entries, 0 to 88755
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   firstCategoryText   88756 non-null  object
#  1   idFirstCategory     88756 non-null  int64
#  2   idSecondCategory    88756 non-null  int64
#  3   idThirdCategory     88756 non-null  int64
#  4   secondCategoryText  88756 non-null  object
#  5   thirdCategoryText   88704 non-null  object
#  6   product_id          88756 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 4.7+ MB

# %%
used_columns = ['rating', 'user_id', 'product_id', 'age', 'gender', 'price', 'brandName', 'idFirstCategory', 'idSecondCategory', 'idThirdCategory']

glowpick_df = total_merged_df.loc [:, used_columns]
glowpick_df.head ()
# Out:
#    rating  user_id product_id   age gender    price          brandName  \
# 0       3   119763     100000  36.0      f  11000.0  해피바스 (HAPPY BATH)
# 1       4   338669     100000  38.0      f  11000.0  해피바스 (HAPPY BATH)
# 2       3    24862     100000  28.0      f  11000.0  해피바스 (HAPPY BATH)
# 3       4  1331797     100000  20.0      f  11000.0  해피바스 (HAPPY BATH)
# 4       4   888968     100000  33.0      f  11000.0  해피바스 (HAPPY BATH)
#
#    idFirstCategory  idSecondCategory  idThirdCategory
# 0              7.0              32.0            112.0
# 1              7.0              32.0            112.0
# 2              7.0              32.0            112.0
# 3              7.0              32.0            112.0
# 4              7.0              32.0            112.0

# %%
users.isnull ().sum ()
# Out:
# age                   0
# birth_year            0
# email                 0
# gender                0
# is_blinded            0
# is_closed             0
# is_inactivated        0
# nickname              1
# profile_image     31585
# rank                  0
# review_count          0
# skin_type             0
# user_id               0
# dtype: int64

# %%
glowpick_df.isnull ().sum ()
# Out:
# rating                   0
# user_id                  0
# product_id               0
# age                 128747
# gender              128747
# price                13683
# brandName            12844
# idFirstCategory      54684
# idSecondCategory     54684
# idThirdCategory      54684
# dtype: int64

# %%
glowpick_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1965802 entries, 0 to 1965801
# Data columns (total 10 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   rating            int64
#  1   user_id           object
#  2   product_id        object
#  3   age               float64
#  4   gender            object
#  5   price             float64
#  6   brandName         object
#  7   idFirstCategory   float64
#  8   idSecondCategory  float64
#  9   idThirdCategory   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 165.0+ MB
