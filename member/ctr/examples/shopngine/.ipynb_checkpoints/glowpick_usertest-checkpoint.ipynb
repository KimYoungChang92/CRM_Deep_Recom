# %%
import sys
sys.path.append("..")

from deepctr_torch.inputs import SparseFeat, VarLenSparseFeat, get_feature_names
from deepctr_torch.models import DeepFM

# %load_ext autoreload
# %autoreload 2
import product_refine

FILE_PATH = '/home/lionkim/data_set/1.HM/glowpick/'
MODEL_PATH ='/home/lionkim/1.hm/advisor/deepFM/DeepCTR/examples/models/DeepFM.pth'

# %% [markdown]
# ### feather 파일로 저장되어있는 각각의 dataframe을 로드

# %%
# %%time
# feather 파일로 저장되어있는 각각의 dataframe을 읽어옴

reviews = pd.read_feather (FILE_PATH + 'reviews.ftr', use_threads = True)
users = pd.read_feather (FILE_PATH + 'users.ftr', use_threads = True)
products = pd.read_feather (FILE_PATH + 'products.ftr', use_threads = True)
products_brand_rank = pd.read_feather (FILE_PATH + 'products_brand_rank.ftr', use_threads = True)
product_categories = pd.read_feather (FILE_PATH + 'product_categories.ftr', use_threads = True)

glowpick_before_labeling = pd.read_feather (FILE_PATH + 'glowpick_before_labeling.ftr', use_threads = True)
glowpick = pd.read_feather (FILE_PATH + 'glowpick.ftr', use_threads = True)

# products와 products_brand_rank를 merge한 dataframe
refined_products = pd.read_feather (FILE_PATH + 'refined_products.ftr', use_threads = True)
# Out:
# CPU times: user 8.32 s, sys: 2.3 s, total: 10.6 s
# Wall time: 10.4 s

# %% [markdown]
# ### 데이터 준비

# %%
sparse_features = ["product_id", "user_id", "gender", "age", "skin_type", "idThirdCategory", ]
target = ['rating']

# %%
# linear_feature_columns list 와 dnn_feature_columns list 를 load
with open (FILE_PATH + 'linear_feature_columns_list.pickle', 'rb') as fp:
    linear_feature_columns = pickle.load (fp)
    
with open (FILE_PATH + 'dnn_feature_columns_list.pickle', 'rb') as fp:
    dnn_feature_columns = pickle.load (fp)    

feature_names = get_feature_names (linear_feature_columns + dnn_feature_columns)

# %%
# 3.generate input data for model
train, test = train_test_split (glowpick, test_size = 0.2)
train_model_input = {name: train [name] for name in feature_names}
test_model_input = {name: test [name] for name in feature_names}

# %% [markdown]
# ### Load Model

# %%
device = 'cpu'
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print('cuda ready...')
    device = 'cuda:0'
# Out:
# cuda ready...

# %%
model = DeepFM (linear_feature_columns, dnn_feature_columns, task = 'regression', device = device)
model.load_state_dict (torch.load (MODEL_PATH))
model.eval ()
# Out:
# DeepFM(
#   (embedding_dict): ModuleDict(
#     (age): Embedding(67, 4)
#     (gender): Embedding(2, 4)
#     (idThirdCategory): Embedding(286, 4)
#     (product_id): Embedding(50761, 4)
#     (skin_type): Embedding(5, 4)
#     (user_id): Embedding(74773, 4)
#   )
#   (linear_model): Linear(
#     (embedding_dict): ModuleDict(
#       (age): Embedding(67, 1)
#       (gender): Embedding(2, 1)
#       (idThirdCategory): Embedding(286, 1)
#       (product_id): Embedding(50761, 1)
#       (skin_type): Embedding(5, 1)
#       (user_id): Embedding(74773, 1)
#     )
#   )
#   (out): PredictionLayer()
#   (fm): FM()
#   (dnn): DNN(
#     (dropout): Dropout(p=0, inplace=False)
#     (linears): ModuleList(
#       (0): Linear(in_features=24, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (activation_layers): ModuleList(
#       (0): ReLU(inplace=True)
#       (1): ReLU(inplace=True)
#     )
#   )
#   (dnn_linear): Linear(in_features=128, out_features=1, bias=False)
# )

# %% [markdown]
# ### 평가

# %%
# epoch 6
from math import sqrt

pred_ans = model.predict (test_model_input, batch_size = 256)

print("test MSE", round (mean_squared_error (test [target].values, pred_ans), 4))

print ("\ntest RMSE", round (sqrt (mean_squared_error (test [target].values, pred_ans)), 4))
# Out:
# test MSE 0.8722
#
# test RMSE 0.9339

# %%
# epoch 6
from math import sqrt

pred_ans = model.predict (test_model_input, batch_size = 256)

print("test MSE", round (mean_squared_error (test [target].values, pred_ans), 4))

print ("\ntest RMSE", round (sqrt (mean_squared_error (test [target].values, pred_ans)), 4))
# Out:
# test MSE 0.867
#
# test RMSE 0.9312

# %% [markdown]
# ### 실제 유저용 메서드

# %%
reviews.head (3)
# Out:
#                                             contents            created_at  \
# 0  티 컬렉션으로 출시되었던 제품으로, 가벼운 녹차향이 납니다. 향 자체는 좀 날리는 ...  2020-04-30T02:12:36Z
# 1  살짝 로션같이 짜지고 묽음.\r\n향은 독하지 않고 적절히 향긋함.\r\n거품잘남\...  2020-03-15T09:08:20Z
# 2  해피바스는 무난하고 순한 매력이 있음! 다른것들도 잘 썼지만 정말 무난함,, 그치만...  2020-01-21T01:29:44Z
#
#    is_evaluation  like_count  rating review_id state user_id product_id
# 0          False           0       3   5416271     N  119763     100000
# 1          False           0       4   5340616     N  338669     100000
# 2          False           0       3   5228598     N   24862     100000

# %%
show_cols = ['created_at', 'rating', 'user_id', 'product_id', 'age', 'gender', 'is_closed', 'skin_type', 'productTitle', 'volume', 'price', 'brandName', 'idThirdCategory']

real_method_df = glowpick_before_labeling [show_cols]
real_method_df.head (3)
# Out:
#              created_at  rating user_id product_id   age gender  is_closed  \
# 0  2020-04-30T02:12:36Z       3  119763     100000  36.0      f      False
# 1  2020-03-15T09:08:20Z       4  338669     100000  38.0      f      False
# 2  2020-01-21T01:29:44Z       3   24862     100000  28.0      f      False
#
#   skin_type       productTitle volume    price          brandName  \
# 0       복합성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0  해피바스 (HAPPY BATH)
# 1        중성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0  해피바스 (HAPPY BATH)
# 2       복합성  티컬렉션 그린티 미셀라 클렌징폼   175g  11000.0  해피바스 (HAPPY BATH)
#
#    idThirdCategory
# 0            112.0
# 1            112.0
# 2            112.0

# %% [markdown]
# #### 특정 유저의 DataFrame 만들기

# %%
REAL_USER_ID = '338669'

real_user_df = real_method_df [real_method_df ['user_id'] == REAL_USER_ID]
real_user_df.head (3)
# Out:
#                created_at  rating user_id product_id   age gender  is_closed  \
# 1    2020-03-15T09:08:20Z       4  338669     100000  38.0      f      False
# 106  2020-01-11T03:03:05Z       5  338669     100020  38.0      f      False
# 133  2019-06-23T07:42:07Z       5  338669     100023  38.0      f      False
#
#     skin_type                 productTitle volume     price  \
# 1          중성            티컬렉션 그린티 미셀라 클렌징폼   175g   11000.0
# 106        중성  로시크숨마 엘릭서 크림 [SPF50+/PA+++]   60ml  350000.0
# 133        중성               로시크숨마 엘릭서 아이크림   25ml  200000.0
#
#              brandName  idThirdCategory
# 1    해피바스 (HAPPY BATH)            112.0
# 106      숨37˚ (sum37˚)             26.0
# 133      숨37˚ (sum37˚)             23.0

# %%
users [users ['user_id'] == '338669']
# Out:
#        age  birth_year                  email gender  is_blinded  is_closed  \
# 8486  38.0      1983.0  hihearyeong@naver.com      f           0      False
#
#       is_inactivated nickname  \
# 8486           False       뭐라
#
#                                           profile_image  rank  review_count  \
# 8486  https://d9vmi5fxk1gsw.cloudfront.net/prod/regi...  1023           285
#
#      skin_type user_id
# 8486        중성  338669

# %%
len (real_user_df)
# Out:
# 151

# %%
len (refined_products)
# Out:
# 86184

# %%
real_user_df.head ()
# Out:
#                  created_at  rating user_id product_id   age gender  \
# 1      2020-03-15T09:08:20Z       4  338669     100000  38.0      f
# 106    2020-01-11T03:03:05Z       5  338669     100020  38.0      f
# 133    2019-06-23T07:42:07Z       5  338669     100023  38.0      f
# 7653   2020-01-11T03:26:35Z       5  338669     100681  38.0      f
# 25326  2018-04-01T13:19:53Z       4  338669      15134  38.0      f
#
#        is_closed skin_type                 productTitle volume     price  \
# 1          False        중성            티컬렉션 그린티 미셀라 클렌징폼   175g   11000.0
# 106        False        중성  로시크숨마 엘릭서 크림 [SPF50+/PA+++]   60ml  350000.0
# 133        False        중성               로시크숨마 엘릭서 아이크림   25ml  200000.0
# 7653       False        중성                자로우 도피러스 이피에스  69.6g   49500.0
# 25326      False        중성                  동백오일 영양 마스크    1ea    1000.0
#
#                        brandName  idThirdCategory
# 1              해피바스 (HAPPY BATH)            112.0
# 106                숨37˚ (sum37˚)             26.0
# 133                숨37˚ (sum37˚)             23.0
# 7653   자로우포뮬러스 (Jarrow Formulas)            269.0
# 25326             일리윤 (ILLIYOON)            128.0

# %%
# 유저가 평가한 상품 id list
print ('평가 상품수: ', real_user_df ['product_id'].nunique ())

predicted_product_list = real_user_df ['product_id'].values.tolist ()
print ('\n', predicted_product_list)
# Out:
# 평가 상품수:  151
#
#  ['100000', '100020', '100023', '100681', '15134', '75699', '103981', '104680', '104943', '106324', '106528', '106568', '106890', '107086', '107622', '107921', '108679', '109444', '10970', '10995', '11051', '111259', '21813', '11422', '11430', '11433', '11434', '114779', '81170', '115285', '116527', '116665', '11754', '120167', '12050', '120774', '120980', '121264', '122722', '124321', '97543', '124756', '125801', '90875', '129986', '2496', '1315', '13205', '13904', '13906', '14321', '1495', '15133', '15980', '15996', '16977', '17742', '24728', '18261', '105840', '92530', '20132', '21500', '21557', '23112', '5866', '2359', '23973', '2447', '24555', '24774', '2493', '2494', '2614', '2616', '27695', '2775', '2855', '3143', '3179', '3195', '3270', '3279', '3333', '34075', '35031', '35610', '38508', '3907', '3975', '3984', '3985', '4136', '4195', '4211', '4226', '42468', '42807', '433', '91750', '104039', '48501', '5259', '5334', '540', '5744', '589', '65977', '6767', '6860', '70449', '70953', '70957', '70961', '71145', '87107', '73508', '73637', '74168', '87992', '77264', '7726', '77347', '78290', '78613', '78844', '79433', '79436', '79629', '81458', '81782', '86095', '86096', '86774', '87248', '89743', '91025', '91262', '91505', '93667', '95559', '96980', '99147', '99560', '99708', '57353', '99620', '110331', '109640', '20846', '81147']

# %%
refined_products [refined_products ['product_id'] == '100020']
# Out:
#       product_id                 productTitle     price volume  \
# 73412     100020  로시크숨마 엘릭서 크림 [SPF50+/PA+++]  350000.0   60ml
#
#                                              description  ratingAvg  \
# 73412  - 피부를 다스리는 순화의 비방 펌 아리쉬타 골드™\r\n- 황제가 누리던 더욱 강...        4.4
#
#        wishCount  reviewCount firstCategoryText  idFirstCategory  \
# 73412          6           15              스킨케어                1
#
#        idSecondCategory  idThirdCategory secondCategoryText thirdCategoryText  \
# 73412                 4               26                 크림           안티에이징크림
#
#        rank                                              brand      brandName
# 73412    81  {'idBrand': None, 'brandTitle': '숨37˚ (sum37˚)...  숨37˚ (sum37˚)

# %%
glowpick_before_labeling ['product_id'].nunique ()
# Out:
# 50761

# %%
review_product_id_list = glowpick_before_labeling ['product_id'].unique()

# %%
len (review_product_id_list)
# Out:
# 50761

# %%
len (refined_products [refined_products ['product_id'].isin (review_product_id_list)])
# Out:
# 50761

# %%
# glowpick_before_labeling은 결측치를 삭제했으므로 refined_products 보다 상품수가 적음
# len (glow_product_id_list) : 50761
# len (refined_products) : 86184
# glowpick_before_labeling에 있는 상품만 가져옴
removed_products = refined_products [refined_products ['product_id'].isin (review_product_id_list)]

# %%
len (refined_products)
# Out:
# 86184

# %%
len (removed_products)
# Out:
# 50761

# %%
removed_products.sort_values ('product_id', axis = 0).head (3)
# Out:
#       product_id       productTitle    price volume  \
# 76792     100000  티컬렉션 그린티 미셀라 클렌징폼  11000.0   175g
# 10353     100002         모이스트 립 글로스   4900.0   3.6g
# 73683     100003  크리스탈 4색 아이섀도우 팔레트   4900.0   6g*4
#
#                                              description  ratingAvg  \
# 76792  연약한 피부, 클렌징부터 다르게!\r\n부드러운 거품의 마일드 솝-프리 폼\r\n\...       3.58
# 10353                               미니소의 모이스트 립 글로스 입니다.       4.00
# 73683                            다양한 색, 다양한 펄감을 팔레트 하나에!       3.33
#
#        wishCount  reviewCount firstCategoryText  idFirstCategory  \
# 76792          2           12               클렌징                7
# 10353          1            1             립메이크업                3
# 73683          0            3            아이메이크업                4
#
#        idSecondCategory  idThirdCategory secondCategoryText thirdCategoryText  \
# 76792                32              112             페이셜클렌저              클렌징폼
# 10353                17               54               립글로스              립글로스
# 73683                22               75              아이섀도우             아이팔레트
#
#        rank                                              brand  \
# 76792   386  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 10353    79  {'idBrand': None, 'brandTitle': '미니소 (MINISO)'...
# 73683   608  {'idBrand': None, 'brandTitle': '미니소 (MINISO)'...
#
#                brandName
# 76792  해피바스 (HAPPY BATH)
# 10353       미니소 (MINISO)
# 73683       미니소 (MINISO)

# %%
100000
99998

# %%
removed_products.sort_values ('product_id', ascending = False).head ()
# Out:
#       product_id          productTitle    price volume  \
# 77611      99998    티컬렉션 그린티 미셀라 클렌징오일  17000.0  200ml
# 41662      99997         이드라 24+ 밤 마스크  69000.0   50ml
# 74513      99995  사파이어 콜라겐 임팩트 에센셜 마스크   3000.0   25ml
# 48449      99994       젤리 페이스 마스크 - 포모      0.0    60g
# 60801      99993   시크리테일 누드 일루미네이팅 파우더  15000.0     9g
#
#                                              description  ratingAvg  \
# 77611  연약한 피부, 클렌징부터 다르게!\r\n피부엔 가볍고 클렌징은 완벽한 라이트 오일\...       3.17
# 41662  피부가 메마를 땐, 수분을 집중할 때!\r\n\r\n산뜻한 젤 타입의 크림 제형이 ...       4.00
# 74513  웰더마에서 직접 개발한 탄력부직포가 적용된 마스크\r\n\r\n- 0.1mm 피부가...       4.43
# 48449        칼라민 파우더가 피부를 진정시켜주고 로즈 추출물이 깨끗한 피부를 만들어줍니다.       3.78
# 60801  미세하고 고운 펄의 은은한 광택이 입체적인 얼굴과 바디라인을 연출해주는 멀티 하이라...       5.00
#
#        wishCount  reviewCount firstCategoryText  idFirstCategory  \
# 77611          2            6               클렌징                7
# 41662          0            1             마스크/팩                8
# 74513          0            7             마스크/팩                8
# 48449          0            9             마스크/팩                8
# 60801          6            1              컨투어링                5
#
#        idSecondCategory  idThirdCategory secondCategoryText thirdCategoryText  \
# 77611                33              118            메이크업클렌저             클렌징오일
# 41662                38              133             페이스마스크              슬리핑팩
# 74513                37              132              시트마스크          안티에이징마스크
# 48449                38              134             페이스마스크             워시오프팩
# 60801                25               81              하이라이터          파우더하이라이터
#
#        rank                                              brand  \
# 77611   358  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 41662   271  {'idBrand': None, 'brandTitle': '빠이요 (PAYOT)',...
# 74513    71  {'idBrand': None, 'brandTitle': '웰더마 (WellDerm...
# 48449   203  {'idBrand': None, 'brandTitle': '러쉬 (LUSH)', '...
# 60801    96  {'idBrand': None, 'brandTitle': '벨 (BELL)', 'b...
#
#                brandName
# 77611  해피바스 (HAPPY BATH)
# 41662        빠이요 (PAYOT)
# 74513    웰더마 (WellDerma)
# 48449          러쉬 (LUSH)
# 60801           벨 (BELL)

# %%
removed_products.sort_values ('product_id', ascending = True).head ()
# Out:
#       product_id        productTitle    price volume  \
# 76792     100000   티컬렉션 그린티 미셀라 클렌징폼  11000.0   175g
# 10353     100002          모이스트 립 글로스   4900.0   3.6g
# 73683     100003   크리스탈 4색 아이섀도우 팔레트   4900.0   6g*4
# 64454     100006      퀸 컬렉션 프레스드 파우더   5900.0    12g
# 7118      100007  올데이 워터프루프 롱래쉬 마스카라   4900.0   8.5g
#
#                                              description  ratingAvg  \
# 76792  연약한 피부, 클렌징부터 다르게!\r\n부드러운 거품의 마일드 솝-프리 폼\r\n\...       3.58
# 10353                               미니소의 모이스트 립 글로스 입니다.       4.00
# 73683                            다양한 색, 다양한 펄감을 팔레트 하나에!       3.33
# 64454  하루종일 보송보송 애기피부로 만들어주는 파우더\r\n\r\n* 전성분은 01 라이트...       4.00
# 7118                               워터프루프로 하루종일 속눈썹 강력고정!       3.00
#
#        wishCount  reviewCount firstCategoryText  idFirstCategory  \
# 76792          2           12               클렌징                7
# 10353          1            1             립메이크업                3
# 73683          0            3            아이메이크업                4
# 64454          1            2           페이스메이크업                2
# 7118           1            2            아이메이크업                4
#
#        idSecondCategory  idThirdCategory secondCategoryText thirdCategoryText  \
# 76792                32              112             페이셜클렌저              클렌징폼
# 10353                17               54               립글로스              립글로스
# 73683                22               75              아이섀도우             아이팔레트
# 64454                 8               37             피니시파우더           프레스드파우더
# 7118                 23               77               마스카라           롱래시마스카라
#
#        rank                                              brand  \
# 76792   386  {'idBrand': None, 'brandTitle': '해피바스 (HAPPY B...
# 10353    79  {'idBrand': None, 'brandTitle': '미니소 (MINISO)'...
# 73683   608  {'idBrand': None, 'brandTitle': '미니소 (MINISO)'...
# 64454   107  {'idBrand': None, 'brandTitle': '미니소 (MINISO)'...
# 7118    170  {'idBrand': None, 'brandTitle': '미니소 (MINISO)'...
#
#                brandName
# 76792  해피바스 (HAPPY BATH)
# 10353       미니소 (MINISO)
# 73683       미니소 (MINISO)
# 64454       미니소 (MINISO)
# 7118        미니소 (MINISO)

# %%
removed_products.describe ()
# Out:
#               price     ratingAvg     wishCount   reviewCount  \
# count  5.076100e+04  50761.000000  50761.000000  50761.000000
# mean   2.824564e+04      3.766675     35.607573     55.540395
# std    4.343287e+04      0.771975    207.493263    309.493091
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    9.000000e+03      3.330000      1.000000      2.000000
# 50%    1.800000e+04      3.910000      3.000000      6.000000
# 75%    3.300000e+04      4.250000     12.000000     21.000000
# max    1.747000e+06      5.000000  12109.000000  17582.000000
#
#        idFirstCategory  idSecondCategory  idThirdCategory          rank
# count     50761.000000      50761.000000     50761.000000  50761.000000
# mean          6.487953         33.503635       108.864463    184.833415
# std           4.792143         26.948915        80.067048    247.597573
# min           1.000000          1.000000         1.000000      0.000000
# 25%           2.000000          7.000000        35.000000      8.000000
# 50%           6.000000         31.000000       109.000000     83.000000
# 75%          10.000000         55.000000       165.000000    266.000000
# max          19.000000        101.000000       306.000000   1397.000000

# %%
reduce_columns = ['product_id', 'idThirdCategory']
reduce_products = removed_products [reduce_columns]
reduce_products.head()
# Out:
#   product_id  idThirdCategory
# 0     108711              255
# 1     118971              255
# 2     118819              255
# 3      90929              255
# 4     127206              255

# %%
len (reduce_products)
# Out:
# 50761

# %%
reduce_products.reset_index (drop = True, inplace = True)
reduce_products
# Out:
#       product_id  idThirdCategory
# 0         108711              255
# 1         118971              255
# 2         118819              255
# 3          90929              255
# 4         127206              255
# ...          ...              ...
# 50756      81005              120
# 50757      24658              120
# 50758       6925              120
# 50759      80493              120
# 50760        433               67
#
# [50761 rows x 2 columns]

# %%
user_reduce_columns = ["user_id", "gender", "age", "skin_type",]
real_user_df = users [users ['user_id'] == '338669'] [user_reduce_columns]
real_user_df.reset_index (drop = True, inplace = True)
real_user_df
# Out:
#   user_id gender   age skin_type
# 0  338669      f  38.0        중성

# %%
reduce_glowpick = pd.concat ([reduce_products, real_user_df], axis = 1)
reduce_glowpick
# Out:
#       product_id  idThirdCategory user_id gender   age skin_type
# 0         108711              255  338669      f  38.0        중성
# 1         118971              255     NaN    NaN   NaN       NaN
# 2         118819              255     NaN    NaN   NaN       NaN
# 3          90929              255     NaN    NaN   NaN       NaN
# 4         127206              255     NaN    NaN   NaN       NaN
# ...          ...              ...     ...    ...   ...       ...
# 50756      81005              120     NaN    NaN   NaN       NaN
# 50757      24658              120     NaN    NaN   NaN       NaN
# 50758       6925              120     NaN    NaN   NaN       NaN
# 50759      80493              120     NaN    NaN   NaN       NaN
# 50760        433               67     NaN    NaN   NaN       NaN
#
# [50761 rows x 6 columns]

# %%
print (dict (zip (real_user_df.columns.tolist(), real_user_df.values.squeeze().tolist ())))
# Out:
# {'user_id': '338669', 'gender': 'f', 'age': 38.0, 'skin_type': '중성'}

# %%
real_user_df.columns.tolist()
# Out:
# ['user_id', 'gender', 'age', 'skin_type']

# %%
user_data_dict = dict (zip (real_user_df.columns.tolist(), real_user_df.values.squeeze().tolist ()))
u_cols = ['user_id', 'gender', 'age', 'skin_type']
reduce_glowpick.fillna (user_data_dict, inplace = True)

# %%
reduce_glowpick
# Out:
#       product_id  idThirdCategory user_id gender   age skin_type
# 0         108711              255  338669      f  38.0        중성
# 1         118971              255  338669      f  38.0        중성
# 2         118819              255  338669      f  38.0        중성
# 3          90929              255  338669      f  38.0        중성
# 4         127206              255  338669      f  38.0        중성
# ...          ...              ...     ...    ...   ...       ...
# 50756      81005              120  338669      f  38.0        중성
# 50757      24658              120  338669      f  38.0        중성
# 50758       6925              120  338669      f  38.0        중성
# 50759      80493              120  338669      f  38.0        중성
# 50760        433               67  338669      f  38.0        중성
#
# [50761 rows x 6 columns]

# %%
reduce_products ['product_id'].nunique ()
# Out:
# 50761

# %%
refined_products ['product_id'].nunique ()

# %%
print ('실제 상품수: ', refined_products ['product_id'].nunique ())

refined_products_list = refined_products ['product_id'].values
refined_products_list
# Out:
# 실제 상품수:  86184
# array(['108711', '118971', '118819', ..., '23249', '73281', '433'],
#       dtype=object)

# %%
len (refined_products)
# Out:
# 86184

# %%
refined_products ['product_id'].isin (predicted_product_list)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 86179    False
# 86180    False
# 86181    False
# 86182    False
# 86183     True
# Name: product_id, Length: 86184, dtype: bool

# %%
removed_products = refined_products [~refined_products ['product_id'].isin (predicted_product_list)]

# %%
refined_products ['product_id'].nunique () - removed_products ['product_id'].nunique ()

# %%
real_fixlen_feature_columns = [SparseFeat (feat, reduce_glowpick [feat].nunique(), embedding_dim=4)
                          for feat in sparse_features]
real_fixlen_feature_columns
# Out:
# [SparseFeat(name='product_id', vocabulary_size=50761, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='product_id', group_name='default_group'),
#  SparseFeat(name='user_id', vocabulary_size=1, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='user_id', group_name='default_group'),
#  SparseFeat(name='gender', vocabulary_size=1, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='gender', group_name='default_group'),
#  SparseFeat(name='age', vocabulary_size=1, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='age', group_name='default_group'),
#  SparseFeat(name='skin_type', vocabulary_size=1, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='skin_type', group_name='default_group'),
#  SparseFeat(name='idThirdCategory', vocabulary_size=286, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='idThirdCategory', group_name='default_group')]

# %%
real_fixlen_feature_columns [1].name
# Out:
# 'user_id'

# %%
reduce_glowpick
# Out:
#       product_id  idThirdCategory user_id gender   age skin_type
# 0         108711              255  338669      f  38.0        중성
# 1         118971              255  338669      f  38.0        중성
# 2         118819              255  338669      f  38.0        중성
# 3          90929              255  338669      f  38.0        중성
# 4         127206              255  338669      f  38.0        중성
# ...          ...              ...     ...    ...   ...       ...
# 50756      81005              120  338669      f  38.0        중성
# 50757      24658              120  338669      f  38.0        중성
# 50758       6925              120  338669      f  38.0        중성
# 50759      80493              120  338669      f  38.0        중성
# 50760        433               67  338669      f  38.0        중성
#
# [50761 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# 1.Label Encoding for sparse features,and process sequence features
for feat in sparse_features:
    lbe = LabelEncoder()
    reduce_glowpick [feat] = lbe.fit_transform (reduce_glowpick [feat])
    
reduce_glowpick.head (3)
# Out:
#    product_id  idThirdCategory  user_id  gender  age  skin_type
# 0        5066              237        0       0    0          0
# 1       10272              237        0       0    0          0
# 2       10183              237        0       0    0          0

# %%
reduce_glowpick.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50761 entries, 0 to 50760
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   product_id       50761 non-null  int64
#  1   idThirdCategory  50761 non-null  int64
#  2   user_id          50761 non-null  int64
#  3   gender           50761 non-null  int64
#  4   age              50761 non-null  int64
#  5   skin_type        50761 non-null  int64
# dtypes: int64(6)
# memory usage: 2.3 MB

# %%
real_model_input = {name: reduce_glowpick [name] for name in feature_names}

# %%
real_model_input
# Out:
# {'product_id': 0         5066
#  1        10272
#  2        10183
#  3        45445
#  4        13837
#           ...
#  50756    39645
#  50757    21907
#  50758    33194
#  50759    39287
#  50760    27573
#  Name: product_id, Length: 50761, dtype: int64,
#  'user_id': 0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  50756    0
#  50757    0
#  50758    0
#  50759    0
#  50760    0
#  Name: user_id, Length: 50761, dtype: int64,
#  'gender': 0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  50756    0
#  50757    0
#  50758    0
#  50759    0
#  50760    0
#  Name: gender, Length: 50761, dtype: int64,
#  'age': 0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  50756    0
#  50757    0
#  50758    0
#  50759    0
#  50760    0
#  Name: age, Length: 50761, dtype: int64,
#  'skin_type': 0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  50756    0
#  50757    0
#  50758    0
#  50759    0
#  50760    0
#  Name: skin_type, Length: 50761, dtype: int64,
#  'idThirdCategory': 0        237
#  1        237
#  2        237
#  3        237
#  4        237
#          ...
#  50756    116
#  50757    116
#  50758    116
#  50759    116
#  50760     66
#  Name: idThirdCategory, Length: 50761, dtype: int64}

# %%
# epoch 10
from math import sqrt

pred_ans = model.predict (real_model_input, batch_size = 256)

# %%
pred_list = list (map (lambda x : round (x, 2), pred_ans.flatten ().tolist ()))   # 예측한 점수 리스트
pred_list
# Out:
# [4.04,
#  3.37,
#  3.52,
#  3.52,
#  3.52,
#  3.6,
#  3.89,
#  3.08,
#  3.68,
#  4.02,
#  4.09,
#  4.04,
#  4.26,
#  4.03,
#  4.05,
#  3.73,
#  4.16,
#  3.99,
#  4.21,
#  4.09,
#  4.34,
#  3.38,
#  4.12,
#  3.9,
#  4.09,
#  3.84,
#  4.0,
#  3.48,
#  2.96,
#  2.27,
#  2.3,
#  4.02,
#  4.11,
#  4.39,
#  3.89,
#  3.43,
#  4.17,
#  3.03,
#  3.05,
#  4.09,
#  4.14,
#  3.95,
#  4.0,
#  4.13,
#  3.48,
#  3.84,
#  3.55,
#  3.42,
#  3.87,
#  3.9,
#  3.81,
#  4.05,
#  3.85,
#  3.91,
#  3.99,
#  3.11,
#  4.11,
#  3.3,
#  3.7,
#  4.03,
#  4.23,
#  3.97,
#  4.1,
#  3.62,
#  3.91,
#  3.85,
#  3.93,
#  4.4,
#  3.94,
#  3.86,
#  3.87,
#  3.79,
#  3.59,
#  3.5,
#  3.95,
#  4.0,
#  3.91,
#  3.46,
#  3.9,
#  3.67,
#  4.2,
#  3.36,
#  4.49,
#  3.54,
#  4.16,
#  4.27,
#  3.73,
#  4.26,
#  3.89,
#  3.82,
#  4.46,
#  3.41,
#  4.17,
#  3.19,
#  3.5,
#  3.63,
#  3.23,
#  4.07,
#  4.08,
#  4.27,
#  4.02,
#  4.22,
#  4.14,
#  4.34,
#  3.41,
#  3.81,
#  4.06,
#  4.43,
#  3.6,
#  3.66,
#  4.38,
#  4.38,
#  4.12,
#  4.3,
#  4.15,
#  3.37,
#  4.16,
#  4.33,
#  4.24,
#  4.58,
#  3.23,
#  3.64,
#  4.18,
#  3.2,
#  3.61,
#  4.43,
#  3.61,
#  4.44,
#  3.99,
#  3.88,
#  3.79,
#  3.89,
#  4.05,
#  3.39,
#  4.44,
#  4.56,
#  4.09,
#  4.22,
#  3.86,
#  3.69,
#  4.08,
#  4.17,
#  3.96,
#  3.55,
#  4.33,
#  4.54,
#  4.43,
#  3.87,
#  3.94,
#  4.29,
#  4.12,
#  3.41,
#  3.46,
#  4.39,
#  3.37,
#  3.84,
#  3.66,
#  3.32,
#  4.45,
#  4.34,
#  3.97,
#  3.75,
#  3.97,
#  4.06,
#  4.34,
#  4.08,
#  4.08,
#  4.1,
#  3.34,
#  3.12,
#  3.89,
#  3.25,
#  4.12,
#  3.11,
#  3.49,
#  3.48,
#  3.38,
#  3.81,
#  4.11,
#  4.12,
#  3.52,
#  4.0,
#  4.1,
#  4.11,
#  4.22,
#  3.99,
#  3.37,
#  3.15,
#  3.17,
#  3.88,
#  3.86,
#  3.75,
#  3.65,
#  3.98,
#  3.52,
#  3.48,
#  2.88,
#  3.4,
#  3.67,
#  2.8,
#  4.48,
#  3.65,
#  4.42,
#  3.88,
#  4.0,
#  4.03,
#  4.01,
#  3.82,
#  3.67,
#  3.48,
#  4.12,
#  4.13,
#  4.01,
#  4.13,
#  3.48,
#  4.16,
#  3.9,
#  3.48,
#  4.13,
#  4.04,
#  4.02,
#  4.1,
#  3.48,
#  4.13,
#  3.48,
#  3.48,
#  4.12,
#  4.11,
#  3.56,
#  3.13,
#  3.67,
#  3.27,
#  3.65,
#  4.04,
#  4.11,
#  3.16,
#  2.8,
#  4.02,
#  3.48,
#  3.8,
#  3.23,
#  3.55,
#  3.57,
#  3.59,
#  3.4,
#  3.48,
#  3.37,
#  3.61,
#  3.48,
#  3.73,
#  3.6,
#  3.42,
#  3.86,
#  3.6,
#  3.7,
#  3.48,
#  3.42,
#  3.28,
#  3.48,
#  3.48,
#  3.48,
#  3.83,
#  3.66,
#  3.57,
#  3.62,
#  3.13,
#  3.48,
#  3.61,
#  4.13,
#  3.41,
#  3.48,
#  3.64,
#  2.76,
#  3.42,
#  2.8,
#  2.78,
#  3.69,
#  3.15,
#  3.13,
#  3.48,
#  3.64,
#  3.52,
#  4.11,
#  4.12,
#  3.42,
#  3.02,
#  2.78,
#  3.48,
#  3.48,
#  2.89,
#  3.48,
#  2.83,
#  3.22,
#  3.48,
#  2.75,
#  3.48,
#  3.02,
#  3.31,
#  3.09,
#  3.14,
#  3.19,
#  3.15,
#  3.46,
#  3.58,
#  2.72,
#  4.14,
#  3.11,
#  3.2,
#  2.93,
#  3.21,
#  3.06,
#  2.69,
#  2.74,
#  2.69,
#  2.89,
#  3.18,
#  3.48,
#  3.48,
#  3.14,
#  3.51,
#  2.96,
#  3.94,
#  3.28,
#  3.46,
#  3.55,
#  2.88,
#  2.5,
#  2.79,
#  3.15,
#  3.39,
#  2.95,
#  2.44,
#  3.55,
#  2.66,
#  2.2,
#  2.93,
#  2.65,
#  3.29,
#  3.19,
#  3.32,
#  2.74,
#  2.6,
#  2.82,
#  3.3,
#  2.5,
#  2.69,
#  2.67,
#  2.77,
#  3.01,
#  2.06,
#  3.37,
#  2.31,
#  2.49,
#  3.02,
#  2.85,
#  2.66,
#  2.5,
#  2.43,
#  3.35,
#  2.82,
#  4.05,
#  3.98,
#  3.79,
#  3.67,
#  3.48,
#  4.12,
#  4.04,
#  4.14,
#  4.19,
#  4.11,
#  3.86,
#  3.83,
#  4.01,
#  3.9,
#  3.79,
#  3.84,
#  3.96,
#  3.88,
#  3.86,
#  3.86,
#  3.93,
#  3.8,
#  3.92,
#  3.95,
#  3.89,
#  3.79,
#  3.72,
#  3.87,
#  3.61,
#  3.23,
#  4.22,
#  3.74,
#  2.67,
#  3.96,
#  3.88,
#  3.92,
#  3.86,
#  3.75,
#  3.59,
#  4.09,
#  3.64,
#  3.56,
#  3.66,
#  4.09,
#  3.57,
#  3.87,
#  4.06,
#  4.13,
#  3.63,
#  3.37,
#  3.67,
#  3.57,
#  3.53,
#  3.86,
#  4.07,
#  3.29,
#  4.01,
#  3.84,
#  3.97,
#  3.39,
#  3.58,
#  3.35,
#  3.74,
#  3.25,
#  3.45,
#  3.6,
#  3.87,
#  3.0,
#  3.46,
#  3.49,
#  3.35,
#  3.26,
#  3.45,
#  3.56,
#  3.97,
#  4.16,
#  3.82,
#  3.58,
#  4.02,
#  3.23,
#  3.52,
#  3.28,
#  3.53,
#  3.53,
#  4.19,
#  3.33,
#  4.07,
#  4.14,
#  4.03,
#  3.48,
#  4.03,
#  3.9,
#  4.05,
#  4.08,
#  4.04,
#  3.35,
#  3.54,
#  3.23,
#  3.97,
#  3.35,
#  3.92,
#  4.09,
#  3.2,
#  3.46,
#  3.6,
#  3.42,
#  3.12,
#  3.46,
#  4.07,
#  3.21,
#  3.84,
#  3.39,
#  4.03,
#  3.99,
#  3.53,
#  3.98,
#  4.03,
#  4.35,
#  3.48,
#  3.96,
#  4.11,
#  3.97,
#  4.47,
#  3.54,
#  3.52,
#  3.37,
#  3.81,
#  3.9,
#  2.79,
#  3.84,
#  4.01,
#  3.39,
#  3.19,
#  3.85,
#  4.04,
#  3.08,
#  3.49,
#  3.63,
#  4.34,
#  3.62,
#  3.81,
#  3.65,
#  3.73,
#  3.67,
#  4.3,
#  4.39,
#  3.9,
#  3.43,
#  3.43,
#  3.41,
#  3.83,
#  3.33,
#  3.63,
#  3.51,
#  3.26,
#  3.99,
#  3.72,
#  3.26,
#  3.65,
#  3.26,
#  3.79,
#  4.2,
#  3.53,
#  3.41,
#  3.14,
#  3.41,
#  3.27,
#  3.97,
#  3.8,
#  3.8,
#  3.87,
#  3.74,
#  3.43,
#  3.88,
#  3.1,
#  3.4,
#  3.97,
#  3.76,
#  3.77,
#  3.29,
#  3.85,
#  3.56,
#  3.66,
#  3.92,
#  3.27,
#  3.93,
#  3.94,
#  3.27,
#  3.38,
#  3.27,
#  2.87,
#  3.49,
#  3.27,
#  4.04,
#  3.44,
#  3.31,
#  3.25,
#  3.04,
#  3.29,
#  2.97,
#  3.92,
#  3.07,
#  3.85,
#  3.13,
#  3.46,
#  3.44,
#  3.27,
#  3.66,
#  3.84,
#  3.27,
#  3.86,
#  3.8,
#  3.54,
#  3.21,
#  3.33,
#  3.69,
#  3.41,
#  2.66,
#  3.29,
#  3.02,
#  3.27,
#  3.43,
#  2.93,
#  3.27,
#  2.82,
#  3.27,
#  3.01,
#  2.73,
#  3.59,
#  3.28,
#  3.18,
#  3.27,
#  3.3,
#  2.59,
#  3.36,
#  2.98,
#  3.21,
#  2.97,
#  3.12,
#  3.27,
#  3.27,
#  3.27,
#  2.57,
#  2.74,
#  2.58,
#  2.53,
#  3.3,
#  3.12,
#  3.27,
#  3.51,
#  4.09,
#  3.11,
#  3.31,
#  3.13,
#  2.61,
#  3.19,
#  3.25,
#  2.63,
#  2.77,
#  3.04,
#  3.21,
#  2.98,
#  2.48,
#  2.18,
#  3.0,
#  3.12,
#  2.98,
#  3.07,
#  2.35,
#  3.13,
#  2.69,
#  3.11,
#  3.16,
#  2.7,
#  2.7,
#  3.08,
#  2.67,
#  2.72,
#  1.94,
#  3.05,
#  1.99,
#  3.02,
#  2.64,
#  2.9,
#  3.0,
#  2.93,
#  1.83,
#  2.42,
#  2.27,
#  2.75,
#  2.8,
#  2.49,
#  2.33,
#  2.27,
#  2.61,
#  2.07,
#  2.04,
#  3.35,
#  3.99,
#  3.99,
#  4.02,
#  3.94,
#  3.74,
#  3.77,
#  3.49,
#  3.71,
#  3.99,
#  3.65,
#  3.75,
#  3.9,
#  3.76,
#  3.11,
#  3.87,
#  3.74,
#  4.17,
#  3.75,
#  3.4,
#  3.74,
#  3.9,
#  3.68,
#  3.46,
#  3.67,
#  3.56,
#  3.63,
#  2.86,
#  3.81,
#  3.54,
#  3.77,
#  3.52,
#  3.61,
#  3.54,
#  3.49,
#  3.29,
#  3.7,
#  3.45,
#  4.02,
#  3.54,
#  3.33,
#  3.53,
#  3.79,
#  3.35,
#  3.42,
#  3.38,
#  3.81,
#  3.29,
#  3.47,
#  3.94,
#  3.99,
#  3.99,
#  3.9,
#  3.35,
#  3.48,
#  4.06,
#  3.15,
#  3.58,
#  3.66,
#  3.14,
#  3.93,
#  3.15,
#  3.36,
#  3.76,
#  4.13,
#  3.55,
#  4.08,
#  3.2,
#  4.11,
#  3.9,
#  3.89,
#  4.05,
#  3.42,
#  3.01,
#  3.9,
#  4.01,
#  3.76,
#  3.25,
#  3.43,
#  3.53,
#  3.98,
#  3.52,
#  4.2,
#  3.36,
#  3.75,
#  3.25,
#  3.0,
#  3.97,
#  3.85,
#  3.48,
#  3.7,
#  3.94,
#  3.41,
#  3.31,
#  3.9,
#  3.59,
#  3.43,
#  3.94,
#  3.89,
#  3.36,
#  4.17,
#  3.33,
#  4.48,
#  4.05,
#  3.25,
#  3.28,
#  4.02,
#  3.5,
#  3.56,
#  3.29,
#  3.36,
#  3.9,
#  3.54,
#  3.82,
#  3.47,
#  3.62,
#  4.12,
#  3.6,
#  3.67,
#  4.12,
#  3.25,
#  3.98,
#  3.58,
#  3.2,
#  3.96,
#  3.46,
#  3.48,
#  4.1,
#  3.35,
#  3.86,
#  3.54,
#  3.96,
#  3.65,
#  3.37,
#  3.37,
#  3.22,
#  4.18,
#  3.82,
#  3.36,
#  3.99,
#  3.57,
#  3.46,
#  3.91,
#  3.55,
#  3.44,
#  3.8,
#  3.52,
#  3.82,
#  3.27,
#  3.41,
#  3.92,
#  3.96,
#  3.91,
#  2.8,
#  3.66,
#  3.75,
#  2.8,
#  3.18,
#  3.52,
#  4.02,
#  3.47,
#  2.91,
#  2.99,
#  3.4,
#  3.17,
#  3.4,
#  3.77,
#  3.89,
#  3.27,
#  3.54,
#  3.27,
#  3.71,
#  3.44,
#  3.35,
#  3.08,
#  3.37,
#  3.11,
#  3.2,
#  3.09,
#  3.23,
#  3.17,
#  3.18,
#  3.27,
#  3.17,
#  3.93,
#  3.97,
#  3.35,
#  3.29,
#  2.71,
#  3.26,
#  3.27,
#  2.83,
#  3.11,
#  3.11,
#  3.67,
#  3.15,
#  2.79,
#  3.11,
#  3.16,
#  2.88,
#  3.18,
#  3.37,
#  3.14,
#  3.25,
#  3.01,
#  2.93,
#  3.21,
#  2.56,
#  3.27,
#  2.66,
#  3.12,
#  3.12,
#  3.27,
#  2.68,
#  3.9,
#  3.32,
#  2.91,
#  3.17,
#  2.8,
#  3.0,
#  2.32,
#  3.12,
#  3.06,
#  2.25,
#  3.01,
#  3.17,
#  2.66,
#  2.57,
#  2.82,
#  2.49,
#  2.45,
#  3.1,
#  2.9,
#  3.17,
#  3.49,
#  3.19,
#  3.14,
#  3.05,
#  2.66,
#  2.25,
#  3.27,
#  3.21,
#  3.05,
#  2.88,
#  2.44,
#  2.97,
#  2.58,
#  2.47,
#  3.18,
#  3.42,
#  3.17,
#  3.14,
#  2.44,
#  3.12,
#  2.67,
#  3.02,
#  2.78,
#  3.08,
#  2.89,
#  2.93,
#  3.01,
#  3.17,
#  2.93,
#  2.6,
#  3.47,
#  2.31,
#  2.41,
#  3.22,
#  2.82,
#  2.98,
#  2.91,
#  3.3,
#  2.76,
#  3.0,
#  2.51,
#  3.02,
#  2.9,
#  3.03,
#  3.11,
#  3.23,
#  2.75,
#  2.37,
#  2.92,
#  1.97,
#  2.47,
#  3.16,
#  2.95,
#  2.78,
#  2.17,
#  2.96,
#  3.04,
#  2.49,
#  3.07,
#  2.78,
#  2.92,
#  2.05,
#  2.11,
#  2.4,
#  2.42,
#  2.19,
#  2.96,
#  2.07,
#  2.46,
#  2.44,
#  2.26,
#  2.85,
#  2.91,
#  2.66,
#  2.77,
#  2.57,
#  2.59,
#  2.3,
#  1.64,
#  2.58,
#  2.14,
#  2.67,
#  1.89,
#  1.89,
#  2.48,
#  2.52,
#  2.58,
#  2.54,
#  2.45,
#  2.51,
#  2.52,
#  2.33,
#  2.51,
#  2.5,
#  2.09,
#  2.41,
#  2.44,
#  2.35,
#  2.24,
#  2.19,
#  2.28,
#  2.21,
#  2.01,
#  2.13,
#  2.05,
#  2.58,
#  1.53,
#  3.91,
#  3.72,
#  ...]

# %%
len (pred_list)
# Out:
# 50761

# %%
reduce_glowpick는 labeling 됐으므로 labeling이 되지 않은 reduce_products와 user_pred_df에서 product_id, user_id를 가져와야 함

# %%
reduce_products
# Out:
#       product_id  idThirdCategory
# 0         108711              255
# 1         118971              255
# 2         118819              255
# 3          90929              255
# 4         127206              255
# ...          ...              ...
# 50756      81005              120
# 50757      24658              120
# 50758       6925              120
# 50759      80493              120
# 50760        433               67
#
# [50761 rows x 2 columns]

# %%
user_pred_df = pd.DataFrame (pred_list, columns = ['rating'])
user_pred_df
# Out:
#        rating
# 0        4.04
# 1        3.37
# 2        3.52
# 3        3.52
# 4        3.52
# ...       ...
# 50756    2.84
# 50757    2.67
# 50758    2.80
# 50759    2.66
# 50760    3.98
#
# [50761 rows x 1 columns]

# %%
user_product_pred_df = pd.concat ([reduce_products, user_pred_df], axis = 1)
user_product_pred_df
# Out:
#       product_id  idThirdCategory  rating
# 0         108711              255    4.04
# 1         118971              255    3.37
# 2         118819              255    3.52
# 3          90929              255    3.52
# 4         127206              255    3.52
# ...          ...              ...     ...
# 50756      81005              120    2.84
# 50757      24658              120    2.67
# 50758       6925              120    2.80
# 50759      80493              120    2.66
# 50760        433               67    3.98
#
# [50761 rows x 3 columns]

# %%
user_product_pred_df.sort_values ('rating', ascending = False, inplace = True)

# %%
user_product_pred_df
# Out:
#       product_id  idThirdCategory  rating
# 1925       26622              247    4.94
# 26767      78768              246    4.94
# 26727      16702              246    4.93
# 11482      41406              153    4.91
# 1923       98519              247    4.91
# ...          ...              ...     ...
# 40741       2606              300    1.24
# 37077      48937               65    1.20
# 31195       7952              179    1.20
# 49525      36000              139    1.16
# 19248      51213              102    1.10
#
# [50761 rows x 3 columns]

# %%
user_product_pred_df
# Out:
#       product_id  idThirdCategory  rating
# 1925       26622              247    4.94
# 26767      78768              246    4.94
# 26727      16702              246    4.93
# 11482      41406              153    4.91
# 1923       98519              247    4.91
# ...          ...              ...     ...
# 40741       2606              300    1.24
# 37077      48937               65    1.20
# 31195       7952              179    1.20
# 49525      36000              139    1.16
# 19248      51213              102    1.10
#
# [50761 rows x 3 columns]

# %%
refined_products.head ()
# Out:
#   product_id          productTitle      price volume  \
# 0     108711          코스메티 LED 마스크   219000.0    1ea
# 1     118971               LED 마스크   149000.0    1ea
# 2     118819  디쎄 1.0 LED 마스크 [업무용]  1320000.0    1ea
# 3      90929            LED 리얼 마스크   198000.0    1ea
# 4     127206     인텐시브 LED 마스크 프리미엄  1517100.0    1ea
#
#                                          description  ratingAvg  wishCount  \
# 0             안면리프팅, 눈가탄력개선, 전피치밀도 수분개선 등에 도움을 주는 제품       3.75          2
# 1  가장 적정거리의 96개의 LED로 피부 침투율을 높여주는 LED 마스크\n\n- 둥...       3.75          0
# 2  하루 한 번 자기전 15분 사용으로 전문적인 케어\r\n\r\n- 3가지 파장으로 ...       5.00          2
# 3  값비싼 피부과 시술, 집에서 손쉽게 할 수 있는 LED 마스크\n\n- 눈가 탄력 ...       4.00          1
# 4  총 480개 LED칩으로 두피부터 얼굴까지 케어해주는 프리미엄 마스크\r\n\r\n...       5.00          1
#
#    reviewCount firstCategoryText  idFirstCategory  idSecondCategory  \
# 0            4              디바이스               16                85
# 1            4              디바이스               16                85
# 2            1              디바이스               16                85
# 3            1              디바이스               16                85
# 4            1              디바이스               16                85
#
#    idThirdCategory secondCategoryText thirdCategoryText  rank  \
# 0              255             뷰티디바이스            LED마스크     5
# 1              255             뷰티디바이스            LED마스크     6
# 2              255             뷰티디바이스            LED마스크     7
# 3              255             뷰티디바이스            LED마스크     8
# 4              255             뷰티디바이스            LED마스크     9
#
#                                                brand               brandName
# 0  {'idBrand': None, 'brandTitle': '아름다운연구소', 'br...                 아름다운연구소
# 1  {'idBrand': None, 'brandTitle': '에끌레어 (eclair)...           에끌레어 (eclair)
# 2  {'idBrand': None, 'brandTitle': '닥터슈라클 (Dr.Ceu...     닥터슈라클 (Dr.Ceuracle)
# 3  {'idBrand': None, 'brandTitle': '솔루미에스테 (SOLLU...  솔루미에스테 (SOLLUME ESTHE)
# 4  {'idBrand': None, 'brandTitle': '엘리닉 (L Linic)...           엘리닉 (L Linic)

# %%
pd.merge (user_product_pred_df, refined_products, how = 'left', on = 'product_id') [['productTitle', 'rating']].head (10)
# Out:
#               productTitle  rating
# 0                 인텐스 히 우드    4.94
# 1         오 도랑쥬 베르트 오 드 코롱    4.94
# 2       쥬 퍼퓸 티아라 느와 오 드 퍼퓸    4.93
# 3  아틀라스 마운틴 로즈 바디 버터_41406    4.91
# 4               토바코 바닐 EDP    4.91
# 5       어드밴스덤 데일리 수분 필링 크림    4.90
# 6              클래식 크림 얼티미트    4.89
# 7                슬림 헤드 눈썹칼    4.89
# 8              에스에너지 클렌징 젤    4.89
# 9               M5001A 플러스    4.88
